# %% [markdown]
# <a href="https://colab.research.google.com/github/DevilCyborg/learning-github/blob/master/FantasyBookersBot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install discord.py==0.16.12

# %%
import random
import time
import asyncio
import json
import discord
import numpy as np

asyncio.set_event_loop(asyncio.new_event_loop())

BOT_PREFIX = "!"
TOKEN = "MzkyNjY2NDg1NjkwMDczMDg4.XK0OEg.Q5Bu5m4136kDzd40_ucSttgn12c"

client = discord.Client()
e = discord.Embed()
# how to embed a file and send it off
#await client.send_message(message.channel, embed=embed)

firstnames = ["Akam", "Apollo", "Baron", "Bo", "Bobby", "Braun", "Brock", "Chad",
              "Curt", "Curtis", "Dash", "Dolph", "Drew", "Elias", "Finn", "Gran" 
              "Heath", "Jinder", "Konnor", "Lince", "Lio", "Mojo", "No Way", 
              "Rezar", "Rhyno", "Roman", "Sami", "Samir", "Joe", "Scott", "Seth",
              "Sunil", "Titus", "Tyler", "Viktor", "Zack", "Aiden", "AJ", 
              "Alexander", "Andrade", "Daniel", "Epico", "Eric", "Jeff", "Jey", 
              "Jimmy", "Karl", "Kevin", "Killian", "Kofi", "Luke", "Matt",
              "Primo", "Randy", "Rey", "Rusev", "Sheamus", "Shelton", "Shinsuke",
              "Sin", "Xavier", "Akira", "Ariya", "Brian", "Jack", "Buddy", "Cedric",
              "Humberto", "Mike", "Oney", "Tony", "John", "Kane", "Lars", "Otis",
              "Tucker", "Triple", "Aleister", "Adam", "Angelo", "Cezar", "Danny",
              "Dominik", "Fabian", "Hanson", "Jaxson", "Johnny", "Keith", "Kona",
              "Kyle", "Marcel", "Montez", "Raul", "Riddick", "Roderick", 
              "Shane", "Steve", "Tino", "Tommaso", "Velveteen", "Wesley", "Kushida",
              "Babatunde", "Punishment", "Trevor", "Fale", "Chase", "Colt",
              "Davey Boy", "David", "Hikuleo", "Hirooki", "Hiroshi", "Hiroyoshi",
              "Jay", "Juice", "Kazuchika", "Kota", "Lance", "Manabu", "Mikey",
              "Minoru", "Satoshi", "Taichi", "Tama", "Tanga", "Tetsuya", "Toa",
              "Togi", "Tomoaki", "Toru", "Tomohiro", "Yoshi", "Yuji", "Yujiro",
              "Ayato", "Chris", "Dragon", "El", "Gedo", "Hiromu", "Jado", "Jushin",
              "Hirai", "Marty", "Ren", "Robbie", "Rocky", "Ryusuke", "Shingo", 
              "Sho", "Shota", "Taiji", "TAKA", "Tiger", "Volador", "Will", "Yoh",
              "Yoshinobu", "Yota", "Yuya", "Akitoshi", "Atsushi", "Go", "Kaito",
              "Katsuhiko", "Kazma", "Kinya", "Masa", "Masao", "Maybach", "Mitsuya",
              "Mohammed", "Naomichi", "Quiet", "Takashi", "Yoshiki", "Daisuke", 
              "Hajime", "Hayata", "Hitoshi", "Junta", "Kotaro", "Seiya", "Tadasuke",
              "Yoshinari", "Ben", "BxB", "Daga", "Don", "Eita", "Flamita", "Gamma",
              "Genki", "Stalker", "Hyo", "Jason", "Johnson", "Kagetora", "Katsumi",
              "Kenichiro", "Kzy", "K-ness", "Masaaki", "Masato", "Mondai", "Naruki",
              "Pac", "Punch", "Ryo", "Shachihoko", "Shun", "Super", "Susumu", 
              "U-T", "Yasushi", "Yosuke", "Yuki", "Ángel", "Atlantis", "Bárbaro",
              "Carístico", "Negro", "Cuatrero", "Diamante", "Ephesto", "Forastero",
              "Hechihero", "L.A.", "Kraneo", "Mephisto", "Michael", "Mr.",
			        "Penta", "Fénix", "Rush", "Sansón", "Shocker",
              "Soberano", "Titán", "Ultimo", "Valiente", "Niebla", "Electrico",
              "Stuka", "Amir", "Ashton", "Dave", "Eddie", "Flash", "Flash Morgan",
              "James", "Jordan", "Joseph", "Kassius", "Kenny", "Mark", "Noam", 
              "Pete", "Sam", "Saxon", "Travis", "Trent", "Tyson", "Walter", 
              "Wolfgang", "Ilja", "Dylan", "Jake", "Jun", "Kai", "Kento", 
              "Masanobu", "Naoya", "Osamu", "Ryoji", "Shuji", "Suwama", "Takao", 
              "Yuma", "Yutaka", "Zeus", "Atsuki", "Black", "Danji", "Hikaru",
              "Hokuto", "Keiichi", "Koji", "Yusuke", "Ace", "Cody", "Dezmond",
              "Ethan", "Fallah", "Josh", "Kongo", "Moose", "Ortiz", "Rich", 
              "Petey", "Rob", "Santana", "Tommy", "Trey", "Willie", "Zachary",
              "Bandido", "Brody", "Bully", "Caprice", "Cheeseburger", "Dalton",
              "Delirious", "Eli", "Flip", "Jonathan", "LSG", "PCO", "NZO", "CazXL",
              "PJ", "Shaheem", "Silas", "TK", "Tracy", "Vinny", "Brandon", 
              "Christopher", "Chuck", "Cima", "Darby", "Frankie", "Joey", 
              "Jungle", "Kip", "Nick", "Maxwell", "Maxwell Jacob", "Sammy", 
              "Scorpio", "Sonny", "Akito", "Antonio", "Cherry", "Danshoku",
              "Gota", "Harashima", "Kazuki", "Kazusada", "Keisuke", "Ken",
              "Konosuke", "Kudo", "Paulie", "Makoto", "Masahiro", "Saki",
              "Sanshiro", "Soma", "Tomomitsu", "Yasu", "Yoshihiko", "Yukio",
              "Yuko", "Yuni", "Andreza", "Mao", "Erik", "Ivar", "Jon", "Alexa",
              "Alicia", "Bayley", "Dana", "Ember", "Liv", "Mickie", "Natalya",
              "Nattie", "Nia", "Ronda", "Ruby", "Sarah", "Sasha", "Tamina",
              "Asuka", "Becky", "Billie", "Carmella", "Charlotte", "Lana", 
              "Mandy", "Naomi", "Peyton", "Sonya", "Zelina", "Beth", "Lacey",
              "Nikki", "Kairi", "Aliyah", "Bianca", "Candice", "Dakota",
              "Deonna", "Io", "Jessamyn", "Kacy", "Marina", "Mia", "Shayna",
              "Taynara", "Vanessa", "Xia", "Chelsea", "Tegan", "Isla", "Jinny",
              "Kelly", "Nina", "Rhea", "Toni", "Jazzy", "Kay Lee", "Piper",
              "Candy", "Arisa", "Bea", "Hana", "Kaori", "Konami", "Kyona",
              "Leo", "Mari", "Mayu", "Momo", "Nao", "Natsuko", "Saki", "Shiki",
              "Sumire", "Tam", "Utami", "Alisha", "Gail", "Jordynne",
              "Katarina", "Kiera", "Madison", "Rosemary", "Courtney", 
              "Scarlett", "Su", "Taya", "Tessa", "Angelina", "Gabby",
              "Jenny", "Jessie", "Stella", "Sumie", "Velvet", "Aja",
              "Allie", "Brandi", "Britt", "Hikaru", "Kylie", "Nyla", 
              "Penelope", "Sadie", "Yuka"
             ]

lastnames = ["Crews", "Corbin", "Dallas", "Lashley", "Roode", "Gable", "Hawkins",
             "Strowman", "Wyatt", "Lesnar", "Axel", "Wilder", "Ziggler", "McIntyre",
             "Fandango", "Balor", "Metalik", "Slater", "Mahal", "Kalisto", "Dorado",
             "Rush", "Rawley", "Jose", "Reigns", "Zayn", "Singh", "Dawson", 
             "Rollins", "O'Neil", "Breeze", "Ryder", "English", "Styles", "Wolfe",
             "Ali", "Cesaro", "Bryan", "Colon", "Young", "Harper", "Hardy", 
             "Uso", "Anderson", "Owens", "Dain", "Kingston", "Gallows", "Orton",
             "Mysterio", "Rowan", "Benjamin", "Nakamura", "Cara", "Woods", 
             "Tozawa", "Daivari", "Kendrick", "Murphy", "Alexander", "Gulak",
             "Gallagher", "Carrillo", "Kanellis", "Lorcan", "Nese", "Cena",
             "Sullivan", "H", "Black", "Ricochet", "Cole", "Dawkins", "Fish",
             "Bononi", "Burch", "Dijakovic", "Aichner", "Ryker", "Gargano", "Lee",
             "Reeves", "O'Reilly", "Barthel", "Riddle", "Ford", "Mendoza", "Moss",
             "Strong", "Rowe", "Thorne", "Cutler", "Sabbatelli", "Ciampa",
             "Dream", "Blake", "Martinez", "Bugenhagen", "Cabana", "Smith",
             "Finlay", "O-Kharn", "Goto", "Tanahashi", "Tenzan", "White", "Cobb",
             "Robinson", "Okada", "Ibushi", "Archer", "Sanada", "Nakanishi", 
             "Nicholls", "Suzuki", "Kojima", "Tonga", "Loa", "Naito", "Henare",
             "Makabe", "Honma", "Yano", "Ishii", "Hashi", "Nagata", "Takahashi",
             "Sabre", "Yoshida", "Bushi", "Sabin", "Desperado", "Phantasmo",
             "Liger", "Kawato", "Scurll", "Narita", "Eagles", "Romero", 
             "Taguchi", "Takagi", "Umino", "Ishimori", "Michinoku", "Mask",
             "Ospreay", "Kanemaru", "Tsuji", "Uemura", "Saito", "Kotoge", 
             "Shiozaki", "Kiyomiya", "Nakajima", "Sakamoto", "Kenoh", 
             "Kitamiya", "Inoue", "Taniguchi", "Nagai", "Yone", "Marufuji",
             "Storm", "Sugiura", "Inamura", "Hino", "Harada", "Ohara", "Kumano",
             "Miyawaki", "Tanaka", "Morohashi", "Ogawa", "Shimizu", "YASSHI", 
             "Hulk", "Fujii", "Kid", "Horiguchi", "Ichikawa", "Florida", 
             "Watanabe", "Ishida", "Takashima", "Arai", "Minoura", "Mochizuki",
             "Yoshino", "Ryu", "Doi", "Tominaga", "Boy", "Skywalker", "Shisa",
             "Yokosuka", "Yamato", "Kanda", "Santa Maria", "Yoshioka", "de Oro",
             "Cavernario", "Panther", "Casas", "Azul", "Guerrero", "Park", "Taven",
             "Elgin", "Niebla", "El 0M", "Bucanero", "Terrible", "Roja", "Jordan",
             "Mastiff", "Dennis", "Webster", "Drake", "Coffey", "Devlin",
             "Conners", "Ohno", "Williams", "Ligero", "Andrews", "Dar", "Dunne",
             "Gradwell", "Huxley", "Banks", "Seven", "Bate", "T-Bone", "Gibson",
             "Dragunov", "James", "Doering", "Akiyama", "Miyahara", "Fuchi", 
             "Nomura", "Nishimura", "Sai", "Ishikawa", "Omori", "Yoshitatsu",
             "Aoyagi", "Yoshie", "Aoki", "Maruyama", "Menso~re", "Tiger",
             "Tamura", "Sato", "Iwamoto", "Tajiri", "Dragon", "Austin", "Cage",
             "Deaner", "Crist", "Xavier", "Edwards", "Page", "Bahh", "Impact",
             "Kross", "Kong", "Fulton", "Swann", "Van Dam", "Callihan", "Dreamer",
             "Miguel", "Mack", "Wentz", "Milonas", "Bruiser", "King", "Ray",
             "Coleman", "Castle", "Isom", "Gordon", "Briscoe", "Lethal", 
             "Gresham", "Haskins", "Titus", "Nova", "Taylor", "O'Ryan",
             "Marseglia", "Ferrara", "Page", "Cutler", "Jericho", "Daniels",
             "Allin", "Kazarian", "Havoc", "Janela", "Omega", "Sabian",
             "Jackson", "Friedmann", "Nakazawa", "Guevara", "Sky", "Kiss",
             "Beretta", "Honda", "Sasaki", "Dino", "Matsuno", "Ihashi",
             "Hirata", "Higuchi", "Ohka", "Takeshita", "Oishi", "Takanashi",
             "Bailey", "Akai", "Takao", "Endo", "Matsunaga", "Owashi", 
             "Urano", "Sakaguchi", "Miyamoto", "Moxley", "Bliss", "Fox",
             "Brooke", "Moon", "Morgan", "Logan", "Jax", "Rousey", "Riott",
             "Neidhart", "Banks", "Snuka", "Lynch", "Kay", "Flair", "Rose",
             "Royce", "Deville", "Vega", "Phoenix", "Evans", "Cross", "Sane",
             "Hojo", "Belair", "LeRae", "Kai", "Purrazzo", "Shirai", "Duke",
             "Catanzaro", "Shafir", "Yim", "Baszler", "Conti", "Borne",
             "Li", "Green", "Nox", "Dawn", "Couture", "Samuels", "Ripley",
             "Brookside", "Gabert", "Ray", "Niven", "Hoshiki", "Priestley",
             "Kimura", "Yoneyama", "Onozaki", "Apache", "Iwatani", "Watanabe",
             "Yamaguchi", "Tora", "Kashima", "Shibusawa", "Natsu", "Nakano",
             "Hayashishita", "Kim", "Grace", "Waters", "Hogan", "Rayne",
             "Bordeaux", "Yung", "Valkyrie", "Blanchard", "Love", "Ortiz",
             "Brooks", "Klein", "Leon", "Grey", "Sakai", "Rhodes", "Baker",
             "Shida", "Rae", "Gibbs", "Sakazaki"
            ]

startnick = ["Big", "The", '"King Of Darkness"', "Bad Luck", "Great",
             "Big R", '"brother"','"Hollywood"', "La Bestia del Ring", 
             "El Hijo de", "Wild Boar", "The Bodyguard", "Killer", "Madman",
             "Beer City", "A-List", "Above Average", "Big Money", "Dangerous", 
             "Die Hard", "Dr.", "Gentleman", "Good Ol'", "Hardcore", "King",
             "Limitless", "Lionheart", "Prince Pretty", "Demon", "Samoa", 
             "Prince", "Speed Star", '"Hangman"', "Super", "Gorgeous",
             "Speedball", "Mad", "The Artist Formerly Known As", "Blackjack",
             "Queen", "Rowdy", "Hot Rod", "Boss", "Iconic", "IIconic",
             "Ravishing", "Golden", "El Hijo del", "Jungle", "Starlight"
            ]

endnick = ["Jr.", "III", "IV", "VII", "Giant Panda"]

wrestlers = {"wwe":["Akam", "Apollo Crews", "Baron Corbin", "Bo Dallas",
                    "Bobby Lashley", "Robert Roode", "Braun Strowman", 
                    "Bray Wyatt","Brock Lesnar", "Chad Gable", "Curt Hawkins",
                    "Curtis Axel", "Dash Wilder", "Dolph Ziggler", 
                    "Drew McIntyre", "Elias", "Finn Balor",
                    "Gran Metalik", "Heath Slater", "Jinder Mahal", 
                    "Kalisto", "Konnor", "Lince Dorado","Lio Rush", 
                    "Mojo Rawley", "No Way Jose", "Rezar", 
                    "Roman Reigns", "Sami Zayn", "Samir Singh", "Scott Dawson",
                    "Seth Rollins", "Sunil Singh", "Titus O'Neil", 
                    "Viktor", "Zack Ryder", "Aiden English", 
                    "AJ Styles", "Ali", "Andrade", "Big E",
                    "Big Show", "Cesaro", "Daniel Bryan", "Epico Colon",
                    "Eric Young", "Harper", "Jeff Hardy", "Jey Uso", 
                    "Jimmy Uso", "Karl Anderson", "Kevin Owens", 
                    "Kofi Kingston", "Luke Gallows",
                    "Matt Hardy", "The Miz", "Primo Colon", "R-Truth",
                    "Randy Orton", "Rey Mysterio", "Rowan", "Rusev", 
                    "Samoa Joe", "Sheamus", "Shelton Benjamin",
                    "Shinsuke Nakamura", "Sin Cara", "Xavier Woods",
                    "Akira Tozawa", "Ariya Daivari", "The Brian Kendrick", 
                    "Buddy Murphy", "Cedric Alexander", "Drew Gulak",
                    "Gentleman Jack Gallagher", "Humberto Carrillo", 
                    "Mike Kanellis", "Oney Lorcan", "Tony Nese","EC3", 
                    "John Cena", "Kane", "Lars Sullivan", "Otis",
                    "Tucker", "The Undertaker", "Triple H", "Aleister Black", 
                    "Ricochet", "Erik", "Ivar"
                   ],
             "nxt": ["Adam Cole", "Angelo Dawkins", 
                    "Bobby Fish", "Cezar Bononi", "Danny Burch",
                    "Dominik Dijakovic", "Jaxson Ryker", "Johnny Gargano", "Keith Lee",
                    "Kona Reeves", "Kyle O'Reilly", 
                    "Matt Riddle", "Montez Ford", "Raul Mendoza", "Riddick Moss", 
                    "Roderick Strong", "Shane Thorne", "Steve Cutler",
                    "Tino Sabbatelli", "Tommaso Ciampa", "Velveteen Dream", 
                    "Wesley Blake", "KUSHIDA", "Babatunde", "Jordan Myles", 
                    "Damien Priest", "Rik Bugez", "Cameron Grimes",
                    "Angel Garza", "Bronson Reed", "Dexter Lumis",
                     "Tyler Breeze", "Fandango", 'Isaiah "Swerve" Scott',
                     "Joaquin Wilde", "Killian Dain", "Mansoor", "Dio Maddin"
                    ],
             
            "njpw":["EVIL", "Bad Luck Fale", "Chase Owens", "Colt Cabana",
                    "Davey Boy Smith Jr.", "David Finlay", "Great O-Kharn",
                    "Hikuleo", "Hirooki Goto", "Hiroshi Tanahashi", 
                    "Hiroyoshi Tenzan", "Jay White", "Jeff Cobb", 
                    "Juice Robinson","Kazuchika Okada", "Kota Ibushi", 
                    "Lance Archer","Manabu Nakanishi", "Mikey Nicholls",
                    "Minoru Suzuki","SANADA", "Satoshi Kojima", "Taichi",
                    "Tama Tonga", "Tanga Loa", "Tetsuya Naito", "Toa Henare",
                    "Togi Makabe", "Tomoaki Honma", "Toru Yano", "Tomohiro Ishii",
                    "Yoshi-Hashi", "Yuji Nagata", "Yujiro Takahashi", 
                    "Zack Sabre Jr.", "Ayato Yoshida", "BUSHI", "Chris Sabin",
                    "Dragon Lee", "El Desperado", "El Phantasmo", "Gedo", 
                    "Hiromu Takahashi", "Jado", "Jushin Thunder Liger",
                    "Hirai Kawato", "Marty Scurll", "Ren Narita", "Robbie Eagles",
                    "Rocky Romero", "Ryusuke Taguchi", "Shingo Takagi", "SHO",
                    "Shota Umino", "Taiji Ishimori", "TAKA Michinoku", 
                    "Tiger Mask", "Volador Jr.", "Will Ospreay", "YOH", 
                    "Yoshinobu Kanemaru", "Yota Tsuji", "Yuya Uemura", "Jon Moxley",
                    "KENTA"
                   ],
             "noah":["Akitoshi Saito", "Atsushi Kotoge", "Cody Hall", "Go Shiozaki",
                     "Kaito Kiyomiya", "Katsuhiko Nakajima", "Kazma Sakamoto",
                     "Kenoh", "Kinya Okada", "Masa Kitamiya", "Masao Inoue",
                     "Maybach Taniguchi", "Mitsuya Nagai", "Mohammed Yone", 
                     "Naomichi Marufuji", "Quiet Storm", "Takashi Sugiura",
                     "Yoshiki Inamura", "Yuji Hino", "Daisuke Harada", 
                     "Hajime Ohara", "HAYATA", "Hi69", "Hitoshi Kumano", 
                     "Junta Miyawaki", "Kotaro Suzuki", "Minoru Tanaka",
                     "Seiya Morohashi", "Tadasuke", "YO-HEY", "Yoshinari Ogawa",
                     "Chris Ridgeway"
                    ],
             "dg": ["Ben-K", "Big R Shimizu", '"brother" YASSHI', "BxB Hulk", 
                    "DAGA", "Don Fujii", "Dragon Kid", "Eita", "Flamita",
                    "Gamma", "Genki Horiguchi", '"Hollywood" Stalker Ichikawa',
                    "Hyo Watanabe", "Jason Lee", "Johnson Florida", "Kagetora", 
                    "Kaito Ishida", "Katsumi Takashima", "Kazma Sakamoto", 
                    "Kenichiro Arai", "Kota Minoura", "Kzy", "K-ness", 
                    "Masaaki Mochizuki", "Masato Yoshino", "Mondai Ryu",
                    "Naruki Doi", "PAC","Punch Tominaga", "Ryo Saito",
                    "Shachihoko Boy", "Shun Skywalker", "Super Shisa",
                    "Super Strong Machine J", "Super Strong Machine F", "Super Strong Machine G",
                    "Susumu Yokosuka","Takashi Yoshida", "U-T", "YAMATO",
                    "Yasushi Kanda", "Yosuke:heart:Santa Maria", "Yuki Yoshioka"
                   ],
             "nxt uk": ["Amir Jordan", "Ashton Smith", "Dave Mastiff", 
                        "Eddie Dennis", "Flash Morgan Webster", "James Drake",
                        "Joe Coffey", "Jordan Devlin", "Joseph Conners", 
                        "Kassius Ohno", "Kenny Williams", "Ligero", "Mark Andrews",
                        "Mark Coffey", "Noam Dar", "Pete Dunne", "Sam Gradwell",
                        "Saxon Huxley", "Travis Banks", "Trent Seven", "Tyler Bate",
                        "Tyson T-Bone", "WALTER", "Wild Boar", "Wolfgang", 
                        "Zack Gibson", "Alexander Wolfe", "Ilja Dragunov", 
                        "Marcel Barthel", "Fabian Aichner", "Primate"
                       ],
             "ajpw": ["The Bodyguard", "Dylan James", "Jake Lee", "Joe Doering",
                     "Jun Akiyama", "KAI", "Kento Miyahara", "Masanobu Fuchi",
                     "Naoya Nomura", "Osamu Nishimura", "Ryoji Sai", "Shuji Ishikawa",
                     "Suwama", "Takao Omori", "Yoshitatsu", "Yuma Aoyagi",
                     "Yutaka Yoshie", "Zeus", "Atsushi Maruyama",
                     "Atsuki Aoyagi", "Black Menso~re", "Black Tiger VII", 
                     "Danji Tamura", "Hikaru Sato", "Hokuto Omori", "Keiichi Sato",
                     "Koji Iwamoto", "Kotaro Suzuki", "Tajiri", "Ultimo Dragon",
                     "Yusuke Okada", "Kazumi Kikuta", "Ryuichi Kawakami"
                     ],
             "impact": ["Ace Austin", "Brian Cage", "Cody Deaner", "DAGA", 
                        "Dave Crist", "Dezmond Xavier", "Eddie Edwards", 
                        "Ethan Page", "Fallah Bahh", "Jake Crist", 
                        "Jake Deaner", "Johnny Impact", "Josh Alexander", 
                        "Killer Kross", "Kongo Kong", "Madman Fulton", "Moose",
                        "Ortiz", "Petey Williams", "Rich Swann", "Rhyno",
                        "Rob Van Dam", "Sami Callihan", "Santana", "Tommy Dreamer",
                        "Trey Miguel", "Willie Mack", "Zachary Wentz"
                       ],
             "roh": ["Bandido", "Beer City Bruiser", "Brian Milonas", "Brody King",
                     "Bully Ray", "Caprice Coleman", "CazXL", "Cheeseburger",
                     "Colt Cabana", "Dalton Castle", "David Finlay", "Delirious",
                     "Eli Isom", "Flip Gordon", "Jay Briscoe", "Jay Lethal",
                     "Jeff Cobb", "Jonathan Gresham", "Josh Woods", "Juice Robinson",
                     "Kenny King", "LSG", "Mark Briscoe", "Mark Haskins", 
                     "Marty Scurll", "Matt Taven", "NZO", "PCO", "PJ Black", 
                     "Rhett Titus", "Rocky Romero", "Rush", "Ryan Nova", 
                     "Shaheem Ali", "Shane Taylor", "Silas Young", "Tama Tonga",
                     "Tanga Loa", "TK O'Ryan", "Tracy Williams", "Vinny Marseglia",
                     "Will Ferrara", "Zack Sabre Jr."
                    ],
             "aew": ['"Hangman" Adam Page', "Angelico", "Brandon Cutler", "Chris Jericho",
                     "Christopher Daniels", "Chuck Taylor", "CIMA", "Cody", 
                     "Darby Allin", "Dustin Rhodes", "Evil Uno", 
                     "Frankie Kazarian", "Isaiah Kassidy", "Jack Evans",
                     "Jimmy Havoc", "Joey Janela", "Jungle Boy", "Kenny Omega",
                     "Kip Sabian", "Luchasaurus", "Marko Stunt", "Marq Quen",
                     "Matt Jackson", "Nick Jackson", "MJF", "Michael Nakazawa", 
                     "PAC", "Penta El 0M", "Fénix", "Sammy Guevara", "Scorpio Sky",
                     "Sonny Kiss", "Trent Beretta", "Jon Moxley", "Peter Avalon",
                     "Shawn Spears", "Stu Grayson", "Orange Cassidy"
                    ],
             "ddt": ["Akito", "Antonio Honda", "Cherry", "Colt Cabana", 
                     "Daisuke Sasaki", "Danshoku Dino", "Gorgeous Matsuno", 
                     "Gota Ihashi", "HARASHIMA", "Hoshitango", "Kazuki Hirata",
                     "Kazusada Higuchi", "Keisuke Ishii", "Ken Ohka",
                     "Konosuke Takeshita", "KUDO", "Ladybeard", "Mad Paulie",
                     "Makoto Oishi", "Masahiro Takanashi", "Mike Bailey", 
                     "Saki Akai", "Sanshiro Takagi", "Shuji Ishikawa",
                     "Soma Takao", "Super Sasadango Machine", "Tetsuya Endo",
                     "Tomomitsu Matsunaga", "Toru Owashi", "Yasu Urano", 
                     "Yoshihiko", "Yukio Sakaguchi", "Yuko Miyamoto", "Yuni",
                     "Andreza Giant Panda", "MAO", "Jiro Ikemen Kuroshio",
                     "Shunma Katsumata", "Nobuhiro Shimatani", "Yuki Ueno",
                     "Naomi Yoshimura", "Mizuki Watase", "Yukio Naya", 
                     "Miyako Matsumoto", "Yuki Iino", "Kouki Iwasaki"
                    ],
             "riptide": ["Ashmore", "Chief Deputy Dunne", "Los Federales Santos Jr",
                         "Mark Davis", "Kyle Fletcher", "Cara Noir", "Cassius",
                         "Chris Brookes", "Connor Mills", "Damon Moser", "David Starr",
                         "Gene Munny", "Jordon Breaks", "Kurtis Chapman",
                         "Lord Gideon Grey", "Mike Bird", "Paul Robinson", 
                         "Rob Lias", "Rocky Mac", "Shay Purser", "Mike Bailey",
                         "Spike Trivet", "A-Kid", "Carlos Romo", "The OJMO", 
                         "TK Cooper", "Chuck Mambo"
                         ]
            }
          

women = {"wwe": ["Alexa Bliss", "Alicia Fox", "Bayley", "Dana Brooke", 
                 "Ember Moon", "Liv Morgan", "Mickie James", "Natalya",
                 "Nia Jax", "Ronda Rousey", "Ruby Riott", "Sarah Logan", 
                 "Sasha Banks", "Tamina", "Asuka", "Becky Lynch", "Billie Kay",
                 "Carmella", "Charlotte Flair", "Lana", "Mandy Rose", "Naomi", 
                 "Peyton Royce", "Sonya Deville", "Zelina Vega", "Beth Phoenix",
                 "Lacey Evans", "Nikki Cross", "Kairi Sane"
                ],
         "nxt": ["Aliyah", "Bianca Belair", "Candice LeRae", "Dakota Kai",
                 "Deonna Purrazzo", "Io Shirai", "Jessamyn Duke", "Kacy Catanzaro",
                 "Marina Shafir", "Mia Yim", "Shayna Baszler", 
                 "Taynara Conti", "Vanessa Borne", "Xia Li", "Chelsea Green",
                 "Tegan Nox", "Rachel Evers"
                ],
         "nxt uk": ["Isla Dawn", "Jinny", "Killer Kelly", "Nina Samuels",
                    "Rhea Ripley", "Toni Storm", "Xia Brookside", "Jazzy Gabert",
                    "Kay Lee Ray", "Piper Niven"
                   ],
         "stardom": ["Arisa Hoshiki", "AZM", "Bea Priestley", "Hana Kimura", "Hanan", "Hazuki", 
                     "Jungle Kyona", "Kagetsu", "Kaori Yoneyama", "Konami", 
                     "Leo Onozaki", "Mari Apache", "Mayu Iwatani", "Momo Watanabe",
                     "Natsuko Tora", "Natsumi", "Ruaka", 
                     "Saki Kashima", "Starlight Kid", "Andras Miyagi",
                     "Sumire Natsu", "Tam Nakano", "Utami Hayashishita", "Riho",
                     "Hina", "Rina", "Saya Iida", "Saya Kamitani"
                    ],
         "impact": ["Alisha Edwards", "Gail Kim", "Jordynne Grace", "Katarina",
                    "Kiera Hogan", "Madison Rayne", "Rosemary", "Scarlett Bordeaux",
                    "Su Yung", "Taya Valkyrie", "Tessa Blanchard"
                   ],
         "roh": ["Angelina Love", "Gabby Ortiz", "Jenny Rose", "Jessie Brooks",
                 "Kelly Klein", "Mandy Leon", "Mayu Iwatani", "Stella Grey", 
                 "Sumie Sakai", "Velvet Sky"
                ],
         "aew": ["Aja Kong", "Awesome Kong", "Allie", "Bea Priestley", 
                 "Brandi Rhodes", "Britt Baker", "Hikaru Shida", "Kylie Rae", 
                 "Leva Bates", "Nyla Rose", "Riho",
                 "Penelope Ford", "Sadie Gibbs", "Yuka Sakazaki"
                ],
         "riptide": ["Candy Floss", "Chakara", "Jinny", "Millie McKenzie",
                     "Session Moth Martina"
                    ]
        }

maineventers = {"wwe": ["Bobby Lashley", "Braun Strowman", "Bray Wyatt",
                        "Brock Lesnar", "Dolph Ziggler", 
                        "Drew McIntyre", "Elias", "Finn Balor",
                        "Roman Reigns", "Sami Zayn", "Seth Rollins",
                        "AJ Styles","Ali", "Andrade", "Big E", "Cesaro",
                        "Daniel Bryan", "Jeff Hardy","Kevin Owens",
                        "Kofi Kingston", "The Miz", "Randy Orton", "Rey Mysterio",
                        "Rusev", "Samoa Joe", "Sheamus", "Shinsuke Nakamura", 
                        "Xavier Woods", "Buddy Murphy", "Cedric Alexander", 
                        "Drew Gulak", "Tony Nese", "EC3", 
                        "John Cena", "Kane", "The Undertaker",
                        "Triple H", "Aleister Black", "Ricochet"
                       ],
                "nxt": ["Adam Cole", "Bobby Fish", "Dominik Dijakovic", 
                        "Johnny Gargano", "Keith Lee", "Kyle O'Reilly", 
                        "Matt Riddle", "Roderick Strong", "Tommaso Ciampa", 
                        "Velveteen Dream", "KUSHIDA", "Cameron Grimes"
                       ],
                "njpw": ["EVIL", "Hirooki Goto", "Hiroshi Tanahashi", "Jay White",
                         "Jeff Cobb", "Juice Robinson", "Kazuchika Okada", 
                         "Kota Ibushi", "Minoru Suzuki", "SANADA", "Taichi",
                         "Tetsuya Naito", "Tomohiro Ishii",
                         "Zack Sabre Jr.", "Hiromu Takahashi", 
                         "Jushin Thunder Liger", "Marty Scurll", "Shingo Takagi",
                         "Taiji Ishimori", "Will Ospreay", "Jon Moxley", "KENTA"
                        ],
                "noah": ["Go Shiozaki", "Kaito Kiyomiya", "Katsuhiko Nakajima",
                         "Kenoh", "Naomichi Marufuji", "Takashi Sugiura",
                         "Daisuke Harada", "Minoru Tanaka"
                        ],
                "dg": ["Ben-K", "Big R Shimizu", "BxB Hulk", "Dragon Kid",
                       "Eita", "Genki Horiguchi", "Kzy", "Masaaki Mochizuki",
                       "Masato Yoshino", "Naruki Doi", "PAC", "Shun Skywalker",
                       "Susumu Yokosuka", "YAMATO", "Yosuke:heart:Santa Maria"
                      ],
                "nxt uk": ["Jordan Devlin", "Kassius Ohno", "Mark Andrews",
                           "Noam Dar", "Pete Dunne", "Travis Banks", 
                           "Trent Seven", "Tyler Bate", "WALTER", "Ilja Dragunov"
                          ],
                "ajpw": ["Joe Doering", "Jun Akiyama", "Kento Miyahara", "Shuji Ishikawa",
                         "Suwama", "Zeus", "Tajiri", "Ultimo Dragon"
                        ],
                "impact": ["Brian Cage", "Eddie Edwards", "Johnny Impact",
                           "Killer Kross", "Moose", "Rich Swann",
                           "Rob Van Dam", "Sami Callihan", "Willie Mack"
                          ],
                "roh": ["Bandido", "Brody King", "Bully Ray", "Colt Cabana",
                        "Dalton Castle", "Jay Lethal", "Jeff Cobb",
                        "Jonathan Gresham", "Juice Robinson", "Mark Haskins", 
                        "Marty Scurll", "Matt Taven", "PCO", "PJ Black", 
                        "Rush", "Silas Young", "Zack Sabre Jr."
                       ],
                "aew": ['"Hangman" Adam Page', "Chris Jericho", 
                        "Christopher Daniels", "CIMA", "Cody", "Kenny Omega", 
                        "PAC", "Penta El 0M", "Fénix", "Jon Moxley"
                       ],
                "ddt": ["Daisuke Sasaki", "Danshoku Dino", "HARASHIMA", 
                        "Konosuke Takeshita", "Sanshiro Takagi", 
                        "Shuji Ishikawa", "Tetsuya Endo", "Yoshihiko", 
                        "Andreza Giant Panda", "Yuni", "Jiro Ikemen Kuroshio"
                       ],
                "riptide": ["Cara Noir", "Chris Brookes", "David Starr",
                            "Jordon Breaks", "Kurtis Chapman", "Paul Robinson", 
                            "Mike Bailey", "Spike Trivet", "The OJMO", 
                            "TK Cooper", "Chuck Mambo"
                           ]
               }

tagteams = {"wwe": {"The Ascension": ["Konnor", "Viktor"],
                    "The Authors of Pain": ["Akam", "Rezar"],
                    "The B-Team":["Bo Dallas", "Curtis Axel"],
                    "The Hardy Boyz": ["Matt Hardy", "Jeff Hardy"],
                    "The Revival": ["Dash Wilder", "Scott Dawson"],
                    "The Singh Brothers": ["Samir Singh", "Sunil Singh"],
                    "The Bar": ["Sheamus", "Cesaro"],
                    "The Bludgeon Brothers": ["Harper", "Rowan"], 
                    "Gallows and Anderson":["Luke Gallows","Karl Anderson"],
                    "The Colons": ["Epico Colon", "Primo Colon"],
                    "The New Day":["Big E", "Kofi Kingston", "Xavier Woods"],
                    "The Usos": ["Jey Uso", "Jimmy Uso"],
                    "Major Bros":["Curt Hawkins", "Zack Ryder"],
                    "Lucha House Party": ["Kalisto", "Gran Metalik", "Lince Dorado"],
                    "The Viking Raiders": ["Erik", "Ivar"],
                    "Daniel Bryan & Rowan": ["Daniel Bryan", "Rowan"],
                    "Heavy Machinery": ["Otis", "Tucker"]
                   },
            "nxt": {"Danny Burch & Oney Lorcan": ["Danny Burch", "Oney Lorcan"],
                    "The Forgotten Sons":["Wesley Blake", "Steve Cutler", "Jaxson Ryker"],
                    "Moss & Sabbatelli":["Riddick Moss", "Tino Sabbatelli"],
                    "Street Profits":["Angelo Dawkins", "Montez Ford"],
                    "The Undisputed ERA":["Bobby Fish", "Kyle O'Reilly", "Roderick Strong"],
                    "Breezango": ["Fandango", "Tyler Breeze"],
                   },
            "njpw": {"EVIL & SANADA":["EVIL", "SANADA"],
                     "FinJuice":["Juice Robinson", "David Finlay"],
                     "TenCozy":["Hiroyoshi Tenzan", "Satoshi Kojima"],
                     "Most Violent Players": ["Togi Makabe", "Toru Yano"],
                     "Great Bash Heel": ["Togi Makabe", "Tomoaki Honma"],
                     "Killer Elite Squad":["Davey Boy Smith Jr.", "Lance Archer"],
                     "Guerrillas Of Destiny":["Tama Tonga", "Tanga Loa"],
                     "Roppongi 3K":["SHO","YOH"],
                     "Shingo Takagi & BUSHI":["BUSHI", "Shingo Takagi"],
                     "Liger & Tiger":["Jushin Thunder Liger", "Tiger Mask"],
                     "Yoshinobu Kanemaru & El Desperado":["Yoshinobu Kanemaru", "El Desperado"],
                     "Jado & Gedo": ["Jado", "Gedo"],
                     "TAKATaichi": ["TAKA Michinoku", "Taichi"],
                     "Taiji Ishimori & El Phantasmo": ["Taiji Ishimori", "El Phantasmo"]
                    },
            "noah": {"The Tough":["Yoshiki Inamura", "Masa Kitamiya"],
                     "AXIZ": ["Katsuhiko Nakajima", "Go Shiozaki"],
                     "50 Funky Powers": ["Mohammed Yone", "Quiet Storm"],
                     "Hooligans":["Maybach Taniguchi", "Yuji Hino"],
                     "Back Breakers":["Hajime Ohara", "Hitoshi Kumano"],
                     "RATEL'S":["HAYATA", "YO-HEY"],
                     "Kotaro Suzuki & Yoshinari Ogawa":["Kotaro Suzuki", "Yoshinari Ogawa"],
                     "The Return Of The Dark Agents": ["Masao Inoue", "Akitoshi Saito"]
                    },
            "dg": {"Speed Muscle":["Masato Yoshino","Naruki Doi"],
                   "Eita & Big R Shimizu":["Eita", "Big R Shimizu"],
                   "YAMAHulk": ["YAMATO", "BxB Hulk"]
                  },
            "nxt uk": {"Grizzled Young Veterans": ["James Drake", "Zack Gibson"],
                       "Coffey Brothers": ["Joe Coffey", "Mark Coffey"],
                       "Moustache Mountain": ["Trent Seven", "Tyler Bate"],
                       "British Strong Style": ["Pete Dunne", "Trent Seven", "Tyler Bate"],
                       "Imperium": ["Marcel Barthel", "Fabian Aichner"],
                       "The Hunt": ["Primate", "Wild Boar"]
                      },
            "ajpw": {"Violent Giants": ["Shuji Ishikawa", "Suwama"],
                     "The Big Guns": ["Zeus", "The Bodyguard"],
                     "Wild Burning": ["Jun Akiyama", "Takao Omori"],
                     "Jake Lee & Koji Iwamoto": ["Jake Lee", "Koji Iwamoto"],
                     "Bomber": ["Dylan James", "Joe Doering"],
                     "YoshiKen": ["Kento Miyahara", "Yoshitatsu"],
                     "Kazumi Kikuta & Ryuichi Kawakami": ["Kazumi Kikuta", "Ryuichi Kawakami"]
                    },
            "impact": {"LAX": ["Santana", "Ortiz"],
                       "oVe": ["Jake Crist", "Dave Crist"],
                       "The Rascalz": ["Dezmond Xavier", "Trey Miguel", "Zachary Wentz"],
                       "The Redneck Renegades": ["Cody Deaner", "Jake Deaner"],
                       "The North": ["Ethan Page", "Josh Alexander"]
                      }, 
            "roh": {"Guerrillas Of Destiny": ["Tama Tonga", "Tanga Loa"],
                    "The Bouncers": ["Beer City Bruiser", "Brian Milonas"],
                    "Villain Enterprises": ["Brody King", "PCO"],
                    "Free AgentZ": ["NZO", "CazXL"],
                    "The Briscoe Brothers": ["Jay Briscoe", "Mark Briscoe"],
                    "The Kingdom": ["TK O'Ryan", "Vinny Marseglia"],
                    "Coast 2 Coast": ["LSG", "Shaheem Ali"]
                   },
            "aew": {"The Young Bucks": ["Matt Jackson", "Nick Jackson"],
                    "Lucha Bros": ["Penta El 0M", "Fénix"],
                    "The Addiction": ["Christopher Daniels", "Frankie Kazarian"],
                    "Best Friends": ["Chuck Taylor", "Trent Beretta"],
                    "The Dark Order": ["Evil Uno", "Stu Grayson"],
                    "Private Party": ["Isaiah Kassidy", "Marq Quen"],
                    "Jack Evans & Angelico": ["Jack Evans", "Angelico"],
                    "A Boy And His Dinosaur": ["Jungle Boy", "Luchasaurus"],
                    "The Brotherhood": ["Cody", "Dustin Rhodes"]
                   },
            "ddt": {"Moonlight Express": ["Mike Bailey", "MAO"],
                    "DAMNATION": ["Daisuke Sasaki", "Soma Takao"]
                   },
            "riptide": {"Anti-Fun Police": ["Chief Deputy Dunne", "Los Federales Santos Jr"],
                        "Aussie Open": ["Kyle Fletcher", "Mark Davis"],
                        "Lord Gideon Grey & Kurtis Chapman": ["Lord Gideon Grey", "Kurtis Chapman"],
                        "Team WhiteWolf": ["A-Kid", "Carlos Romo"]
                       }
             }

titles = {"wwe": {"WWE Championship": ["Kofi Kingston", "ME"],
                  "WWE Intercontinental Championship": ["Shinsuke Nakamura", "MID"],
                  "WWE RAW Tag Team Championship": ["The Revival", "TAG"],
                  "WWE SmackDown Tag Team Championship": ["The New Day", "TAG"],
                  "WWE United States Championship": ["AJ Styles", "MID"],
                  "WWE Universal Championship": ["Seth Rollins", "ME"],
                  "WWE RAW Women's Championship": ["Becky Lynch", "W"],
                  "WWE SmackDown Women's Championship": ["Bayley", "W"]
                 },
          "nxt": {"NXT Championship": ["Adam Cole", "ME"],
                  "NXT North American Championship": ["Velveteen Dream", "MID"],
                  "NXT Tag Team Championship": ["Street Profits", "TAG"],
                  "NXT Women's Championship": ["Shayna Baszler", "W"]
                 },
          "njpw": {"IWGP Heavyweight Championship": ["Kazuchika Okada", "ME"],
                   "IWGP Intercontinental Championship": ["Tetsuya Naito", "MID"],
                   "IWGP Junior Heavyweight Championship": ["Will Ospreay", "MID"],
                   "IWGP Junior Heavyweight Tag Team Championship": ["Taiji Ishimori & El Phantasmo", "TAG"],
                   "IWGP Tag Team Championship": ["Guerrillas Of Destiny", "TAG"],
                   "IWGP United States Heavyweight Championship": ["Jon Moxley", "MID"],
                   "NEVER Openweight Championship": ["Tomohiro Ishii", "MID"],
                   "NEVER Openweight 6-Man Tag Team Championship": [["Ryusuke Taguchi", "Togi Makabe", "Toru Yano"], "TRIO"]
                  },
          "noah": {"GHC Heavyweight Championship": ["Kaito Kiyomiya", "ME"],
                   "GHC Junior Heavyweight Championship": ["HAYATA", "MID"],
                   "GHC Junior Heavyweight Tag Team Championship": ["Kotaro Suzuki & Yoshinari Ogawa", "TAG"],
                   "GHC Tag Team Championship": ["AXIZ", "TAG"]
                  },
          "dg": {"Open The Dream Gate Championship": ["Ben-K", "ME"],
                 "Open The Brave Gate Championship": ["Susumu Yokosuka", "MID"],
                 "Open The Twin Gate Championship": ["Eita & Big R Shimizu", "TAG"],
                 "Open The Triangle Gate Championship": [["Strong Machine F", "Strong Machine G", "Strong Machine J"], "TRIO"]
                },
          "nxt uk": {"WWE United Kingdom Championship": ["WALTER", "ME"],
                     "NXT UK Tag Team Championship": ["Grizzled Young Veterans", "TAG"],
                     "NXT UK Women's Championship": ["Toni Storm", "W"]
                    },
          "ajpw": {"AJPW Triple Crown Championship": ["Kento Miyahara", "ME"],
                   "AJPW World Tag Team Championship": ["Violent Giants", "TAG"],
                   #"AJPW World Junior Heavyweight Championship": ["Atsushi Aoki", "MID"],
                   "AJPW All Asia Tag Team Championship": ["Jake Lee & Koji Iwamoto", "TAG"],
                   "AJPW Gaora TV Championship": ["Yoshitatsu", "MID"]
                  },
          "stardom": {"World of Stardom Championship": ["Bea Priestley", "W"],
                      "Wonder of Stardom Championship": ["Arisa Hoshiki", "W"],
                      "High Speed Championship": ["Riho", "W"],
                      "SWA World Championship": ["Utami Hayashishita", "W"],
                      "Future of Stardom Championship": ["Utami Hayashishita", "W"]
                     },
          "impact": {"Impact World Championship": ["Brian Cage", "ME"],
                     "Impact World Tag Team Championship": ["The North", "TAG"],
                     "Impact X Division Championship": ["Jake Crist", "MID"],
                     "Impact Knockouts Championship": ["Taya Valkyrie", "W"]
                    },
          "roh": {"ROH World Championship": ["Matt Taven","ME"],
                  "ROH World Television Championship": ["Shane Taylor", "MID"],
                  "ROH World Tag Team Championship": ["The Briscoe Brothers", "TAG"],
                  "ROH Women Of Honor World Championship": ["Kelly Klein", "W"],
                  "ROH World 6-Man Tag Team Championship": [["Brody King", "Marty Scurll", "PCO"], "TRIO"]
                 },
          "ddt": {"KO-D Openweight Championship": ["Konosuke Takeshita", "ME"],
                  "DDT Extreme Championship": ["Jiro Ikemen Kuroshio", "MID"],
                  "KO-D Tag Team Championship": ["DAMNATION", "TAG"],
                  "KO-D 6-Man Tag Team Championship": [["Konosuke Takeshita", "Shunma Katsumata", "Yuki Iino"], "TRIO"]
                 },
          "riptide": {"Riptide Brighton Championship": ["Chuck Mambo", "ME"]
                     }
         }

stables = {"njpw": {"Los Ingobernables de Japon": ["Tetsuya Naito", "EVIL", "BUSHI", "SANADA", "Hiromu Takahashi", "Shingo Takagi"],
                    "CHAOS": ["Kazuchika Okada", "Toru Yano", "Tomohiro Ishii", "Yoshi-Hashi", "SHO", "YOH", "Rocky Romero", "Hirooki Goto", "Will Ospreay", "Mikey Nicholls", "Robbie Eagles"],
                    "Bullet Club": ["Bad Luck Fale", "Tama Tonga", "Yujiro Takahashi", "Taiji Ishimori", "Tanga Loa", "Chase Owens", "Jay White", "Gedo", "Jado", "Hikuleo", "El Phantasmo", "KENTA"],
                    "Suzuki-Gun": ["Minoru Suzuki", "TAKA Michinoku", "Taichi", "Lance Archer", "Davey Boy Smith Jr.", "El Desperado", "Yoshinobu Kanemaru", "Zack Sabre Jr."],
                    "Taguchi Japan": ["Ryusuke Taguchi", "Hiroshi Tanahashi", "David Finlay", "Juice Robinson"]
                   },
           "nxt uk": {"British Strong Style": ["Pete Dunne", "Tyler Bate", "Trent Seven"],
                      "Gallus": ["Joe Coffey", "Mark Coffey", "Wolfgang"],
                      "Imperium": ["WALTER", "Marcel Barthel", "Fabian Aichner", "Alexander Wolfe"]
                     },
           "nxt": {"The Undisputed ERA": ["Adam Cole", "Kyle O'Reilly", "Bobby Fish", "Roderick Strong"],
                   "The Forgotten Sons": ["Wesley Blake", "Jaxson Ryker", "Steve Cutler"]
                  },
           "wwe": {"Lucha House Party": ["Kalisto", "Gran Metalik", "Lince Dorado"],
                   "The New Day": ["Kofi Kingston", "Big E", "Xavier Woods"],
                   "The O.C.": ["AJ Styles", "Luke Gallows", "Karl Anderson"]
                  },
           "dg": {"R.E.D": ["PAC", "Eita", "Big R Shimizu", "Takashi Yoshida", "Yasushi Kanda", "Kazma Sakamoto", "DAGA"],
                  "Tribe Vanguard": ["YAMATO", "BxB Hulk", "Yosuke:heart:Santa Maria", "Flamita", "U-T", "Kagetora"],
                  "MaxiMuM": ["Naruki Doi", "Masato Yoshino", "Dragon Kid", "Jason Lee", "Kaito Ishida"],
                  "Natural Vibes": ["Kzy", "Genki Horiguchi", "Susumu Yokosuka", '"brother" YASSHI', "Punch Tominaga"],
                  "Mochizuki Dojo": ["Masaaki Mochizuki", "Kota Minoura", "Hyo Watanabe", "Yuki Yoshioka"],
                  "Super Strong Machines": ["Super Strong Machine J", "Super Strong Machine F", "Super Strong Machine G"]
                 },
           "noah": {"RATEL'S": ["Daisuke Harada", "YO-HEY", "HAYATA", "Tadasuke"],
                    "Kongoh": ["Kenoh", "Masa Kitamiya", "Yoshiki Inamura"],
                    "STINGER": ["Yoshinari Ogawa", "Kotaro Suzuki", "Chris Ridgeway", "Atsushi Kotoge"]
                   },
           "ajpw": {"Evolution": ["Suwama", "Hikaru Sato", "Yusuke Okada"],
                    "Sweeper": ["Jake Lee", "Keiichi Sato", "Koji Iwamoto", "Ryoji Sai", "Naoya Nomura"]
                   },
           "impact": {"The Rascalz": ["Dezmond Xavier", "Zachary Wentz", "Trey Miguel"],
                      "oVe": ["Sami Callihan", "Jake Crist", "Dave Crist", "Madman Fulton"]
                     },
           "roh": {"Lifeblood": ["Juice Robinson", "David Finlay", "Bandido", "Mark Haskins", "Tracy Williams"],
                   "Villain Enterprises": ["Marty Scurll", "Brody King", "PCO", "Flip Gordon"],
                   "The Kingdom": ["Matt Taven", "TK O'Ryan", "Vinny Marseglia"],
                   "Shinobi Shadow Squad": ["Cheeseburger", "Eli Isom", "Ryan Nova"]
                  },
           "aew": {"The Elite": ["Kenny Omega", "Cody", "Matt Jackson", "Nick Jackson", '"Hangman" Adam Page'],
                   "SoCal Uncensored": ["Christopher Daniels", "Frankie Kazarian", "Scorpio Sky"]
                  },
           "ddt": {"DAMNATION": ["Daisuke Sasaki", "Shuji Ishikawa", "Mad Paulie", "Tetsuya Endo", "Soma Takao", "Nobuhiro Shimatani"],
                   "DISASTER BOX": ["HARASHIMA", "Toru Owashi", "Kazuki Hirata"],
                   "Shuten Doji": ["KUDO", "Masahiro Takanashi", "Yukio Sakaguchi", "Saki Akai"],
                   "ALL OUT": ["Konosuke Takeshita", "Akito", "Yuki Iino", "Shunma Katsumata"]
                  },
           "riptide": {"Money Versus Everybody": ["Spike Trivet", "Damon Moser", "Shay Purser"]
                      }
          }

finishers = {"Akam": "Pumphandle Death Valley Bomb", "Apollo Crews": "Gorilla Press Drop Followed By A Standing Moonsault", "Baron Corbin": "End Of Days", 
             "Bo Dallas": "Rollin' The Dice", "Bobby Lashley": "Spear", "Robert Roode": "Glorious DDT", "Braun Strowman": "Running Powerslam", 
             "Bray Wyatt": "Sister Abigail", "Brock Lesnar": "F5", "Chad Gable": "Chaos Theory", "Curt Hawkins": "Heatseeker Elbow Drop",
             "Curtis Axel": "Axelizer", "Dash Wilder": "Gory Bomb", "Dolph Ziggler": "Zig Zag", "Drew McIntyre": "Claymore Kick", "Elias": "Drift Away",
             "Fandango": "The Last Dance", "Finn Balor": "Coup de Grâce",  "Dustin Rhodes": "Final Cut", "Gran Metalik": "Metalik Driver", "Heath Slater": "Smash Hit",
             "Jinder Mahal": "Khallas",  "Kalisto": "Salida Del Sol", "Konnor": "Fall Of Man", "Lince Dorado": "Golden Rewind", "Lio Rush": "Rush Hour", 
             "Mojo Rawley": "Killer Instinct", "No Way Jose": "Fastball Punch", "Rezar": "Powerbomb", "Rhyno": "Gore", "Roman Reigns": "Spear", "Sami Zayn": "Helluva Kick", 
             "Samir Singh": "Jumping DDT", "Scott Dawson": "Cradle DDT", "Seth Rollins": "Curb Stomp", "Sunil Singh": "Golden Liontamer", "Titus O'Neil": "Clash of The Titus",
             "Tyler Breeze": "Beauty Shot", "Viktor": "Fade To Black", "Zack Ryder": "Rough Ryder", "Aiden English": "Director's Cut", 
             "AJ Styles": "Phenomenal Forearm", "Alexander Wolfe": "Cave Canem", "Ali": "054", "Andrade": "Hammerlock DDT", "Big E": "Big Ending",
             "Big Show": "WMD", "Cesaro": "Neutralizer", "Daniel Bryan": "LeBell Lock", "Epico Colon": "Back Stabber", "Eric Young": "The Edge Of Sanity",
             "Harper": "Discus Clothesline", "Jeff Hardy": "Swanton Bomb", "Jey Uso": "Diving Splash", "Jimmy Uso": "Diving Splash", "Karl Anderson": "Gun Stun", 
             "Kevin Owens": "Pop-Up Powerbomb", "Killian Dain": "Cú Chulainn's Wrath", "Kofi Kingston": "Trouble In Paradise", "Luke Gallows": "Gallows Pole",
             "Matt Hardy": "Twist Of Fate", "The Miz": "Skull Crushing Finale", "Primo Colon": "Backstabber", "R-Truth": "What's Up?", "Randy Orton": "RKO",
             "Rey Mysterio": "619", "Rowan": "Full Nelson Slam", "Rusev": "The Accolade", "Samoa Joe": "Coquina Clutch", "Sheamus": "Brogue Kick",
             "Shelton Benjamin": "Paydirt", "Shinsuke Nakamura": "Kinshasa", "Sin Cara": "High-angle senton bomb", "Xavier Woods": "Lost In The Woods",
             "Akira Tozawa": "Diving Senton", "Ariya Daivari": "Cobra Clutch", "The Brian Kendrick": "Captain's Hook", "Buddy Murphy": "Murphy's Law",
             "Cedric Alexander": "Lumbar Check", "Drew Gulak": "Gu-Lock", "Gentleman Jack Gallagher": "Crossface Chickenwing", 
             "Humberto Carrillo": "Corner Headstand Transitioned Into A Split-Legged Moonsault", "Mike Kanellis": "Power Of Love",
             "Oney Lorcan": "Half Boston Crab", "Tony Nese": "The Running Kneese","EC3": "The One Percent", "John Cena": "Attitude Adjustment",
             "Kane": "Chokeslam From Hell", "Lars Sullivan": "Freak Accident", "Otis": "Dozer Bomb", "Tucker": "Project Mayhem",
             "The Undertaker": "Tombstone Piledriver", "Triple H": "Pedigree", "Aleister Black": "Black Mass", "Ricochet": "630 Senton", 
             "Erik": "Death Rowe", "Ivar": "Spin Kick Of Doom", "Alexa Bliss": "DDT", "Alicia Fox": "Watch Yo' Face", "Bayley": "Bayley-To-Belly",
             "Dana Brooke": "Samoan Driver", "Ember Moon": "The Eclipse", "Liv Morgan": "Jersey Codebreaker", "Mickie James": "Mick Kick",
             "Natalya": "Sharpshooter", "Nia Jax": "Leg Drop", "Ronda Rousey": "Armbar", "Ruby Riott": "Riott Kick", "Sarah Logan": "Kentucky Knee", 
             "Sasha Banks": "Bank Statement", "Tamina": "Superfly Splash", "Asuka": "Asuka Lock", "Becky Lynch": "Dis-Arm-Her", "Billie Kay": "Shades Of Kay",
             "Carmella": "Code Of Silence", "Charlotte Flair": "Figure 8 Leglock", "Lana": "Sit-Out Facebuster", "Mandy Rose": "The Bed Of Roses", 
             "Naomi": "Rear View", "Peyton Royce": "Peyton-Plex", "Sonya Deville": "Square-Up Kick", "Zelina Vega": "Fly Cutter", "Beth Phoenix": "Glam Slam",
             "Lacey Evans": "The Woman's Right", "Nikki Cross": "The Purge", "Kairi Sane": "Insane Elbow","The Ascension": "Fall Of Man",
             "The Authors of Pain": "The Last Chapter", "The B-Team": "Belly-To-Back Suplex/Neckbreaker Combo", "The Hardy Boyz": "Twist Of Fate/Swanton Bomb Combo",
             "Breezango": "Beauty in Motion/Last Dance", "The Revival": "Shatter Machine", "The Singh Brothers": "", "The Bar": "", "The Bludgeon Brothers": "The Bludgeoning",          
             "Gallows and Anderson": "Magic Killer", "The Colons": "Double Backstabber", "The New Day": "UpUpDownDown", "SAnitY": "Devastation", "The Usos": "Uso Crazy",
             "Major Bros": "", "Lucha House Party": "", "The Viking Raiders": "Fallout", "Adam Cole": "Last Shot", "Angelo Dawkins": "Sitdown Powerbomb", 
             "Bobby Fish": "Sleeping With The Fishes", "Cezar Bononi": "Hu3 Driver", "Danny Burch": "London Bridge", "Dominik Dijakovic": "Feast Your Eyes",
             "Fabian Aichner": "Hasta La Vista", "Hanson": "Spin Kick Of Doom", "Jaxson Ryker": "No Remorse", "Johnny Gargano": "Garga-No Escape", "Keith Lee": "Ground Zero",
             "Kona Reeves": "Hawaiian Drop", "Kyle O'Reilly": "ARMageddon", "Marcel Barthel": "Axel Dieter Sr. Special", "Matt Riddle": "Bromission", 
             "Montez Ford": "Frog Splash", "Raul Mendoza": "Suplex Into Backbreaker", "Riddick Moss": "Powerslam", "Roderick Strong": "End Of Heartache",
             "Rowe": "Death Rowe", "Shane Thorne": "Black Swan Splash", "Steve Cutler": "The Trademark Plex", "Tino Sabbatelli": "Final Cut", 
             "Tommaso Ciampa": "Project Ciampa", "Velveteen Dream": "The Purple RainMaker", "Wesley Blake": "Frog Splash", "KUSHIDA": "Hoverboard Lock", 
             "Babatunde": "Spinebuster", "Jordan Myles": "The Best 450 Ever", "Damien Priest": "South of Heaven", "Rik Bugez": "Air Guitar", "Cameron Grimes": "Orange Crush",
             'Isaiah "Swerve" Scott': "Swerve Stomp", "Angel Garza": "El Muertito", "Bronson Reed": "Death Drop Driver", "Dexter Lumis": "Breaking Point",
             "Joaquin Wilde": "Filipino Destroyer", "Mansoor": "Running Superkick", "Dio Maddin": "Nico-Nico Knee", "Aliyah": "Arabian Night", "Bianca Belair": "Kiss Of Death", 
             "Candice LeRae": "Ms. LeRae's Wild Ride", "Dakota Kai": "Kai-Ropractor", "Deonna Purrazzo": "Fujiwara Armbar", "Io Shirai": "Moonsault Double Stomp",
             "Jessamyn Duke": "Roundhouse Kick", "Kacy Catanzaro": "Victory Roll", "Marina Shafir": "Armbar", "Mia Yim": "Seoul Food", "Shayna Baszler": "Kirifuda Driver", 
             "Taynara Conti": "Tayogoshi", "Vanessa Borne": "Regalplex Slam", "Xia Li": "Tornado Kick", "Chelsea Green": "Unprettier", "Tegan Nox": "The Shiniest Wizard",
             "Rachel Evers": "Bosswoman Slam",
             "Danny Burch & Oney Lorcan": "Assisted Spike DDT", "The Forgotten Sons": "", "Moss & Sabbatelli": "", "Street Profits": "Backdrop Into Moonsault",
             "The Undisputed ERA": "High/Low", "War Raiders": "Fallout", "EVIL": "Everything is Evil", "Bad Luck Fale": "Grenade", "Chase Owens": "Package Piledriver",
             "Colt Cabana": "Colt .45", "Davey Boy Smith Jr.": "Bulldog Bomb", "David Finlay": "Prima Nocta", "Great O-Kharn": "Argentine Neckbreaker",
             "Hikuleo": "T-Bomb", "Hirooki Goto": "GTR", "Hiroshi Tanahashi": "High Fly Flow", "Hiroyoshi Tenzan": "TTD", "Jay White": "Blade Runner", 
             "Jeff Cobb": "Tour Of The Islands", "Juice Robinson": "Pulp Friction", "Kazuchika Okada": "Rainmaker", "Kota Ibushi": "Kamigoye", 
             "Lance Archer": "Dark Days", "Manabu Nakanishi": "Mount Fuji Suplex", "Mikey Nicholls": "Mikey Bomb", "Minoru Suzuki": "Gotch Piledriver", 
             "SANADA": "Skull End", "Satoshi Kojima": "Koji Cutter", "Taichi": "Black Mephisto", "Tama Tonga": "Gun Stun", "Tanga Loa": "Apeshit", 
             "Tetsuya Naito": "Destino", "Toa Henare": "Toa Bomb", "Togi Makabe": "King Kong Knee Drop", "Tomoaki Honma": "Honma Clutch", "Toru Yano": "Kagamiwari",
             "Tomohiro Ishii": "Brainbuster", "Yoshi-Hashi": "Karma", "Yuji Nagata": "Nagata Lock", "Yujiro Takahashi": "Pimp Juice", "Zack Sabre Jr.": "Zack Driver",
             "Ayato Yoshida": "Scissors Kick", "BUSHI": "MX", "Chris Sabin": "All Hail Sabin", "Dragon Lee": "Dragon Driver", "El Desperado": "Guitarra de Angel",
             "El Phantasmo": "Cutter", "Gedo": "Gedo Clutch", "Hiromu Takahashi": "Time Bomb", "Jado": "Green Killer", "Jushin Thunder Liger": "Liger Bomb",
             "Hirai Kawato": "Dreamcast", "Marty Scurll": "Crossface Chickenwing", "Ren Narita": "Boston Crab", "Robbie Eagles": "Warp 4.5",
             "Rocky Romero": "Foreign Devil", "Ryusuke Taguchi": "Dodon", "Shingo Takagi": "Last Of The Dragon", "SHO": "Shock Arrow", "Shota Umino": "Boston Crab",
             "Taiji Ishimori": "Bloody Cross", "TAKA Michinoku": "Michinoku Driver II", "Tiger Mask": "Millennium Suplex", "Volador Jr.": "La Quebrada",
             "Will Ospreay": "OsCutter", "YOH": "Five Star Clutch", "Yoshinobu Kanemaru": "Touch Out", "Yota Tsuji": "Boston Crab", "Yuya Uemura": "Boston Crab",
             "EVIL & SANADA": "Magic Killer", "FinJuice": "", "TenCozy": "Ten-Cozy Driver", "Most Violent Players": "", "Great Bash Heel": "Kokeshi Impact",
             "Killer Elite Squad": "Killer Bomb", "Guerrillas Of Destiny": "Guerrilla Warfare", "Roppongi 3K": "3K", "Shingo Takagi & BUSHI": "", "Liger & Tiger": "",
             "Yoshinobu Kanemaru & El Desperado": "", "Jado & Gedo": "", "TAKATaichi": "", "Akitoshi Saito": "Death Brand", "Atsushi Kotoge": "Dragstar",
             "Go Shiozaki": "Go Flasher", "Kaito Kiyomiya": "King's Road", "Katsuhiko Nakajima": "Vertical Spike", "Kazma Sakamoto": "Kazmax", "Kenoh": "Ragou",
             "Kinya Okada": "Dropkick", "Masa Kitamiya": "Sasorigatame", "Masao Inoue": "Backbreaker rack", "Maybach Taniguchi": "Maybach Bomb Zwei", 
             "Mitsuya Nagai": "Makai Driver", "Mohammed Yone": "Kinniku Buster", "Naomichi Marufuji": "Emerald Flowsion", "Quiet Storm": "SCD", 
             "Takashi Sugiura": "Ankle Lock", "Yoshiki Inamura": "Suplex", "Yuji Hino": "Fucking Bomb", "Daisuke Harada": "Katayama German Suplex Hold", 
             "Hajime Ohara": "Devil Ray", "HAYATA": "Moonsault Press", "Hi69": "Maharaja", "Hitoshi Kumano": "Kumagatame", "Junta Miyawaki": "",
             "Kotaro Suzuki": "Blue Destiny", "Minoru Tanaka": "Tornado Kaki Cutter", "Seiya Morohashi": "Coral Driver", "Tadasuke": "Psycho Killer", "YO-HEY": "Ganmen G",
             "Yoshinari Ogawa": "V1 Armlock", "Aggression": "Double Running Bulldog", "AXIZ": "", "50 Funky Powers": "Funky Buster Bomb", "Hooligans": "",
             "Back Breakers": "", "RATEL'S": "Wheelbarrow Facebuster/Cutter Combination", "Kotaro Suzuki & Yoshinari Ogawa": "", "Ben-K": "Ben-K Bomb", 
             "Big R Shimizu": "Big R Press", '"brother" YASSHI': "Nice Jamaica", "BxB Hulk": "EVO", "DAGA": "Mataleón", "Don Fujii": "Nodowa Otoshi",
             "Dragon Kid": "Ultra Hurricanrana", "Eita": "Apocalypsis", "Flamita": "Flam Fly", "Gamma": "Blitzen", "Genki Horiguchi": "Backslide From Heaven", 
             '"Hollywood" Stalker Ichikawa': "Ina Bauer German Suplex Hold", "Hyo Watanabe": "Dropkick", "Jason Lee": "MaxiMuM Driver", 
             "Johnson Florida": "Spinning Fisherman Buster", "Kagetora": "Genkonitteki", "Kaito Ishida": "Tiger Suplex", "Katsumi Takashima": "Dropkick",
             "Kenichiro Arai": "Hanshin Tiger Suplex", "Kota Minoura": "Front Suplex", "Kzy": "Kzy Time", "K-ness": "Aoki Hikari", "Masaaki Mochizuki": "Twister II",
             "Masato Yoshino": "Torbellino", "Mondai Ryu": "Problem Dragon Shooting Star Press", "Naruki Doi": "Bakatare Sliding Kick", "PAC": "Black Arrow",
             "Punch Tominaga": "PT Kick", "Ryo Saito": "SaiRyo Rocket", "Shachihoko Boy": "SHACHIHOKO", "Shun Skywalker": "Ashla", "Super Shisa": "Shisa Clutch",
             "Susumu Yokosuka": "Yokosuka Cutter", "Takashi Yoshida": "Cyber Bomb", "U-T": "Skayde", "YAMATO": "Gallaria", "Yasushi Kanda": "Ryu's", 
             "Yosuke:heart:Santa Maria": "Neraiuchi", "Yuki Yoshioka": "Diving Body Splash", "Big Ben": "Pop-Up Into Spear", "Speed Muscle": "Torbellino/Bakatare Sliding Kick",
             "Ángel de Oro": "La Mecedora", "Atlantis": "La Atlántida", "Bárbaro Cavernario": "Cavernaria", "La Bestia del Ring": "Powerslam", 
             "Blue Panther": "El Nudo Lagunero", "Carístico": "La Mistica", "Negro Casas": "La Casita", "Cuatrero": "Cutthroat Codebreaker", "Diamante Azul": "German Suplex",
             "Ephesto": "Shoulderbreaker", "Forastero": "Juji Gatame", "Gran Guerrero": "Pumphandle Cutter", "Hechicero": "El Conjuro", "El Hijo de L.A. Park": "Canadian Destroyer",
             "Kraneo": "Gory Special", "Matt Taven": "Climax", "Mephisto": "Boston Crab", "Michael Elgin": "Elgin Bomb", "Místico": "Estrella Fugaz", "Mr. Niebla": "La Nieblina",
             "L.A. Park": "Code Red", "Penta El 0M": "Pentagon Driver", "Rey Bucanero": "Buca Storm", "Fénix": "Fénix Driver", "Rush": "La Lanza", "Sansón": "Poder Dinamita",
             "Shocker": "La Reinera", "Soberano Jr.": "Moonsault", "El Terrible": "La Terriblina", "Titán": "El Inmortal", "Último Guerrero": "Guerrero Special", 
             "Valiente": "Valiente Driver", "Niebla Roja": "Campana Invertida", "Electrico": "Springboard Splash", "Stuka Jr.": "Moonsault Plancha", "Diamante Azul & Valiente": "",
             "Los Hijos del Inferno": "", "La Sangre Dinamita": "", "Amir Jordan": "Magic Carpet Ride", "Ashton Smith": "Cool Runnings", "Dave Mastiff": "Discus Lariat",
             "Eddie Dennis": "Neck Stop Driver", "Flash Morgan Webster": "Britpop Drop", "James Drake": "Mr. Mayhem", "Joe Coffey": "All The Best For The Bells", 
             "Jordan Devlin": "Ireland's Call", "Joseph Conners": "Righteous Kill", "Kassius Ohno": "Rolling Elbow", "Kenny Williams": "Swinging DDT", "Ligero": "Mexican Wave",
             "Mark Andrews": "Slam to Win", "Mark Coffey": "Crowning Glory", "Noam Dar": "Champagne Superkneebar", "Pete Dunne": "Bitter End", "Sam Gradwell": "Fly 'n' Die",
             "Saxon Huxley": "Desolation Peak", "Travis Banks": "Kiwi Crusher", "Trent Seven": "Seven Stars Lariat", "Tyler Bate": "Tyler Driver '97",
             "Tyson T-Bone": "Gypsy's Kiss", "WALTER": "Golden Bomb", "Wild Boar": "Trapper Keeper", "Wolfgang": "The Howling", "Zack Gibson": "Helter Skelter", 
             "Ilja Dragunov": "Torpedo Moskau", "Primate": "Spear", "Grizzled Young Veterans": "", "Coffey Brothers": "", "Moustache Mountain": "", "British Strong Style": "",
             "Isla Dawn": "Call Of The Quarters",
             "Jinny": "Facelift", "Killer Kelly": "Superkick", "Nina Samuels": "Hell To The Knee-na", "Rhea Ripley": "Riptide", "Toni Storm": "Storm Zero",
             "Xia Brookside": "Brookside Bomb", "Jazzy Gabert": "The Omega Plex", "Kay Lee Ray": "Gory Bomb", "Piper Niven": "Snake Bite", "The Bodyguard": "The Bounce", 
             "Dylan James": "Jurassic Bomb", "Jake Lee": "High Angle Backdrop", "Joe Doering": "Revolution Bomb", "Jun Akiyama": "Blue Thunder Driver", "KAI": "Meteor Impact",
             "Kento Miyahara": "Break Heart", "Masanobu Fuchi": "Bridging Belly-To-Back Suplex", "Naoya Nomura": "Maximum", "Osamu Nishimura": "Cobra Twist", "Ryoji Sai": "Nachi Waterfall",
             "Shuji Ishikawa": "Splash Mountain", "Suwama": "Last Ride", "Takao Omori": "Axe Bomber", "Yoshitatsu": "Yoshitatsu Fantasy", "Yuma Aoyagi": "Rockstar Buster",
             "Yutaka Yoshie": "Canadian Hammer", "Zeus": "Jackhammer", "Atsushi Aoki": "Assault Point", "Atsushi Maruyama": "Akuma Kumikyo", "Atsuki Aoyagi": "Rockstar Buster",
             "Black Menso~re": "Rollup", "Black Tiger VII": "Black Tiger Bomb", "Danji Tamura": "", "Hikaru Sato": "Ude-Hishigi-Gyaku-Juji-Gatame", "Hokuto Omori": "", 
             "Keiichi Sato": "Shouha", "Koji Iwamoto": "Deadlift German Suplex", "Tajiri": "Buzzsaw Kick", "Ultimo Dragon": "Asai DDT", "Yusuke Okada": "Sudden Death",
             "Violent Giants": "Last Mountain", "The Big Guns": "Muscle Explosion", "Wild Burning": "", "Jake Lee & Koji Iwamoto": "", "Bomber": "", "YoshiKen": "",
             "Arisa Hoshiki": "1399", "AZM": "Triple Jump Crossbody", "Hana Kimura": "Ground Manjikatame", "Hanan": "Double Wrist Armsault", "Hazuki": "Atomic Bombs Away", 
             "Jungle Kyona": "Hammer Throw Powerbomb", "Kagetsu": "Ebisu Drop", "Kaori Yoneyama": "Yone-Zou", "Konami": "Fisherman Suplex Hold", "Leo Onozaki": "Ace Crusher",
             "Mari Apache": "Moonsault Bodyblock", "Mayu Iwatani": "Dragon Suplex Hold", "Momo Watanabe": "B Driver", "Nao Yamaguchi": "Axe Bomber", "Natsuko Tora": "Diving Body Press",
             "Natsumi": "El Nudo", "Ruaka": "Dropkick", "Saki Kashima": "Diving Hurricanrana", "Shiki Shibusawa": "Dropkick", "Starlight Kid": "Dropkick",
             "Sumire Natsu": "Dropkick", "Tam Nakano": "Cutter", "Utami Hayashishita": "Argentine Backbreaker","Ace Austin": "House of Cards", "Brian Cage": "Weapon X",
             "Cody Deaner": "Unemployment", "Dave Crist": "Casket Cutter", "Dezmond Xavier": "Final Flash", "Eddie Edwards": "Die Hard", "Ethan Page": "Head Shot",
             "Fallah Bahh": "The Manilla Sunset", "Jake Crist": "Rope Hung Neckbreaker", "Jake Deaner": "Unemployment", "Johnny Impact": "Starship Pain", "Josh Alexander": "Pearl River Plunge", 
             "Killer Kross": "Doomsday Saito", "Kongo Kong": "The Cracker-Jack", "Madman Fulton": "Spinning Gutwrench Suplex", "Moose": "Game Breaker",
             "Ortiz": "Blockbuster", "Petey Williams": "Canadian Destroyer", "Rich Swann": "Five Star Swann Splash", "Rob Van Dam": "Five-Star Frog Splash", 
             "Sami Callihan": "Cradle Killer", "Santana": "Blockbuster", "Tommy Dreamer": "Death Valley Driver", "Trey Miguel": "Meteora", "Willie Mack": "Chocolate Thunder Bomb",
             "Zachary Wentz": "Thnks Fr Th Mmrs", "Alisha Edwards": "Guillotine Drop", "Gail Kim": "Air Raid Crash", "Jordynne Grace": "Fall From Grace", "Katarina": "Kat Nip",
             "Kiera Hogan": "Face The Music", "Madison Rayne": "Rayne Check", "Rosemary": "The Red Wedding", "Scarlett Bordeaux": "DDT", "Su Yung": "Panic Switch",
             "Taya Valkyrie": "Road to Valhalla", "Tessa Blanchard": "Buzzsaw", "LAX": "Elevated Blockbuster", "oVe": "Irish Air Raid", 
             "Lucha Bros": "Package Piledriver/Diving Double Foot Stomp", "The Rascalz": "Hot Fire Flame", "The Redneck Renegades": "", "Bandido": "Revolution Fly",
             "Beer City Bruiser": "Sitout Chokeslam", "Brian Milonas": "Baldo Bomb", "Brody King": "All Seeing Eye", "Bully Ray": "Bully Bomb", "Caprice Coleman": "Thermal Shock",
             "CazXL": "East River Crossing", "Cheeseburger": "Shotei Palm Strike", "Dalton Castle": "Bang-A-Rang", "Delirious": "Chemical Imbalance II",
             "Eli Isom": "Brainbuster", "Flip Gordon": "Star-Spangled Stunner", "Jay Briscoe": "J-Driller", "Jay Lethal": "Lethal Combination", "Jonathan Gresham": "Octopus Hold", 
             "Josh Woods": "Knee Bar", "Kenny King": "Royal Flush", "LSG": "450 Splash", "Mark Briscoe": "Mark-Out", "Mark Haskins": "Pumphandle Driver", 
             "NZO": "JawdonZo", "PCO": "PCOsault", "PJ Black": "Black Diamond", "Rhett Titus": "Muff Driver", "Ryan Nova": "Running Knee", 
             "Shaheem Ali": "Swing-Out Slam", "Shane Taylor": "Greetings from 216", "Silas Young": "Pee Gee Waja Plunge", "TK O'Ryan": "Glue Factory", 
             "Tracy Williams": "Crossface", "Vinny Marseglia": "The Shining", "Will Ferrara": "Sunset Flip Powerbomb", "Angelina Love": "Botox Injection", "Gabby Ortiz": "Dropkick", 
             "Jenny Rose": "Spear", "Jessie Brooks": "Dragon Suplex", "Kelly Klein": "Rainbow Cross", "Mandy Leon": "Astral Projection", "Velvet Sky": "In Yo' Face",
             "The Bouncers": "", "Villain Enterprises": "", "Free AgentZ": "Bada-Boom Shakalaka", "The Briscoe Brothers": "Redneck Boogie", "The Kingdom": "Rock Star Supernova",
             "Coast 2 Coast": "", '"Hangman" Adam Page': "Rite of Passage", "Brandon Cutler": "Wipeout", "Chris Jericho": "Codebreaker", "Christopher Daniels": "Angel's Wings",
             "Chuck Taylor": "Omega Driver", "CIMA": "Egoist Schwein", "Cody": "Cross Rhodes", "Darby Allin": "Last Supper", "Frankie Kazarian": "Back to the Future",
             "Jimmy Havoc": "Acid-Rainmaker", "Joey Janela": "Package Piledriver", "Jungle Boy": "Springboard Backstabber", "Kenny Omega": "One-Winged Angel", 
             "Kip Sabian": "Sliced Bread", "Matt Jackson": "Superkick", "Nick Jackson": "450 Splash", "MJF": "Friedman Armbar Special", "Michael Nakazawa": "Firebird Splash", 
             "Sammy Guevara": "Running Curb Stomp", "Scorpio Sky": "Fatal Answer", "Sonny Kiss": "Sonny Side Up", "Trent Beretta": "Dudebuster", 
             "Aja Kong": "Uraken", "Allie": "Allie Drop", "Bea Priestley": "Flawless Victory", "Brandi Rhodes": "Shot of Brandi", "Britt Baker": "Rainbaker",
             "Hikaru Shida": "Tamashii no Three Count", "Kylie Rae": "Crossface", "Nyla Rose": "Camel Clutch", "Penelope Ford": "Handspring Elbow", 
             "Sadie Gibbs": "Dropkick", "Yuka Sakazaki": "Magical Girl Splash", "The Young Bucks": "Meltzer Driver", "The Addiction": "Bad Elimination", "Best Friends": "Strong Zero",
             "Akito": "Perfect Figure Four", "Antonio Honda": "Backdrop", "Cherry": "Cherryton Bomb", "Daisuke Sasaki": "Now or Never", "Danshoku Dino": "Danshoku Driver",
             "Gorgeous Matsuno": "Gorgeous Star Elbow", "Gota Ihashi": "Dead End", "HARASHIMA": "Somato", "Hoshitango": "Buenos Aires Gozen Reiji", "Kazuki Hirata": "Miracle One",
             "Kazusada Higuchi": "Goten", "Keisuke Ishii": "Exploder", "Ken Ohka": "Spear of Fire", "Konosuke Takeshita": "Surprise Rose", "KUDO": "Diving Double Knee Drop",
             "Ladybeard": "Rollup", "Mad Paulie": "Paulie Buster", "Makoto Oishi": "Grand Cross 200", "Masahiro Takanashi": "Bacchus", "Mike Bailey": "Ultima Weapon", 
             "Saki Akai": "Diving Cross Body", "Sanshiro Takagi": "Dangerous Dragon Sleeper Takagi", "Soma Takao": "Gin & Tonic", "Super Sasadango Machine": "F5",
             "Tetsuya Endo": "Sky Twisted Press", "Tomomitsu Matsunaga": "Golden Arm Bomber", "Toru Owashi": "Asama Yama", "Yasu Urano": "Yasu Pack", 
             "Yoshihiko": "Front Flip Piledriver", "Yukio Sakaguchi": "Kami no Migi Hiza", "Yuko Miyamoto": "Fire Thunder", "Yuni": "Boston Crab",
             "Andreza Giant Panda": "Headbutt", "MAO": "Cannonball 450", "Moonlight Express": "Skylab Hurricane", "DAMNATION": "", "Imperium": "", "YAMATO & KAI": "", "Stella Grey": "",
             "Daniel Bryan & Rowan": "", "The North": "", "Eita & Big R Shimizu": "Starmine", "Jon Moxley": "Paradigm Shift", "Kazumi Kikuta": "", "Ryuichi Kawakami": "", "Kazumi Kikuta & Ryuichi Kawakami": "",
             "Angelico": "Cruceta Invertidas", "Jack Evans": "Ode To Blitzkrieg", "Jack Evans & Angelico": "", "Evil Uno": "Electric Chair Ushigoroshi", "Stu Grayson": "Final Smash", 
             "The Dark Order": "The Fatality", "Isaiah Kassidy": "", "Marq Quen": "", "Private Party": "", "Luchasaurus": "Extinction", "A Boy And His Dinosaur": "", 
             "Marko Stunt": "", "Peter Avalon": "Marti-Knees", "Shawn Spears": "The Perfect 10", "Awesome Kong": "Awesome Bomb", "Riho": "Northern Light Suplex", "Penelope Ford": "Stunner",
             "Leva Bates": "Critical Confirmation", "KENTA": "Go 2 Sleep", "Super Strong Machine J": "Majin Fusha Gatame", "Super Strong Machine F": "", "Super Strong Machine G": "",
             "Jiro Ikemen Kuroshio": "Ikemen Slash", "Ashmore": "", "Chief Deputy Dunne": "Superkick", "Los Federales Santo Jr": "", "Anti-Fun Police": "", 
             "Mark Davis": "Close Your Eyes And Count To Fuck", "Kyle Fletcher": "", "Aussie Open": "Fidget Spinner", "Cara Noir": "", "Cassius": "", 
             "Chris Brookes": "Octopus Stretch", "Connor Mills": "", "Damon Moser": "", "David Starr": "Product Placement", "Gene Munny": "Ainsley Lariat", "Jordon Breaks": "European Clutch",
             "Kurtis Chapman": "SEGA Mega Driver", "Lord Gideon Grey": "", "Lord Gideon Grey & Kurtis Chapman": "", "Mike Bird": "Frog Splash", "Paul Robinson": "Curb Stomp",
             "Rob Lias": "", "Rocky Mac": "TKO", "Shay Purser": "", "Team WhiteWolf": "", "A-Kid": "", "Carlos Romo": "", "The OJMO": "Half-Crab", "Spike Trivet": "Birthright",
             "TK Cooper": "RockPaperScissors Kick", "Chuck Mambo": "Chuck You", "Candy Floss": "Candy Snap", "Chakara": "Widow's Peak", "Millie McKenzie": "Front Flip Piledriver",
             "Session Moth Martina": "Satellite DDT", "Orange Cassidy": "Canadian Destroyer", "YAMAHulk": "EVO x Gallaria", "Saya Iida": "Iidabashi", "Hina": "", "Rina": "",
             "Saya Kamitani": "", "Taiji Ishimori & El Phantasmo": "", "The Tough": "", "Chris Ridgeway": "Niykee Heaton Driver", "The Return Of The Dark Agents": ""
            }


gimmickmatches = ["Falls Count Anywhere Match", "Flag Match", 
                  "60 Minute Iron Man Match", "Lumberjack Match",
                  "Barbed Wire Steel Cage Match", "Fans Bring The Weapons Match",
                  "First Blood Match", "Last Man Standing Match", 
                  "No Disqualification Match","Taipei Deathmatch", 
                  "Submission Match", "Scaffold Match", "Street Fight", 
                  "Parking Lot Brawl", "Ladder Match", "TLC Match", 
                  "Strap Match", "Tables Match", "Steel Cage Match", 
                  "Hell In A Cell Match", "Inferno Match", 
                  "Punjabi Prison Match", "Buried Alive Match", "Casket Match",
                  "Dream Match", "{} On A Pole Match", 
                  "Once In A Lifetime Match", "Ultimate Submission Match",
                  "Empty Arena Match", "Unsanctioned Match", 
                  "30 Minute Iron Man Match", "Tuxedo Match", 
                  "Arm Wrestling Match", "Boxing Match", "MMA Match", 
                  "Sumo Match", "No Countout Match", 
                  "Barbed Wire Massacre Match", '"I Quit" Match', 
                  "Loser Leaves Town Match", "Retirement Match", 
                  "Kiss My Ass Match", "Boiler Room Brawl", "Belfast Brawl",
                  "Trick Or Street Fight", "Miracle On 34th Street Fight", 
                  "Pillow Fight", "Chairs Match", "Straitjacket Match",
                  "Taped Fist Match", "Electrified Cage Match", 
                  "Ambulance Match", "Dumpster Match", "Stretcher Match",
                  "2/3 Falls Match", 
                  "Best Seven Out Of Thirteen Falls Match", 
                  "Five O'Clock Somewhere Last Man Standing Match",
                  "One Minute Time Limit Match", "Yuletide Deathmatch", 
                  "Anything Goes Deathmatch", "Musical Chairs Match",
                  "Explosive Barbed Wire Deathmatch", "Rock Paper Scissors Match",
                  "Thumb War", "Panty Hunt Tiger Cub Rope Deathmatch",
                  "Bra And Panties Match", "Bikini Match", 
                  "Stockholm Style Kiss Kiss Bang Bang Deathmatch", 
                  "Texas Torture My Best Friend Deathmatch", "Trampoline Match",
                  "Alley Fight", "Aussie Rules Match", "Badstreet Brawl",
                  "Bar Room Brawl", "Barbed Wire Deathmatch", "Barbed Wire Cage Match",
                  "Bullrope Match", "Coal Miner's Glove Match", "Dog Collar Match", 
                  "Evening Gown Match", "Exploding Deathmatch", "Extreme Rules Match",
                  "Five Minute Challenge Match", "Foam Party Match", "Full Metal Mayhem Match",
                  "Guerrilla Warfare Match", "Hardcore Match", "High Incident Match",
                  "House Of Fun Match", "Indian Strap Match", "7 Day Iron Man Match",
                  "Las Vegas Gamble Match", "Light Tube Deathmatch", "Lingerie Match",
                  "Monster's Ball Match", "Mud Wrestling Match", "No Rope Barbed Wire Deathmatch",
                  "Overhead Wires Match", "Shoot Fight", "Texas Death Match",
                  "Ultimate Submission Match", "Yogi Yogi Deathmatch", "Pride on the Line Match",
                  "Ultimate Royal Barbed Wire PowerPoint No Power Blast PWF Rules Match",
                  "Four Corners Four Items Deatmatch", "Kiss Pin Match",
                  "Rock 'N' Roll Deathmatch", "Fluorescent Light Tubes, Roses & Ecosystem Deathmatch"
                 ]

venues = {"England": {"O2 Arena": ["London, England", 
                                   "https://vignette.wikia.nocookie.net/prowrestling/images/6/69/O2_Arena.jpg"],
                      "Royal Albert Hall": ["London, England", 
                                            "https://vignette.wikia.nocookie.net/prowrestling/images/c/c8/Royal_Albert_Hall.jpg"],
                      "Wembley Stadium": ["London, England", 
                                          "https://vignette.wikia.nocookie.net/prowrestling/images/6/6d/WembleyStadiumViewFromWembleyWay.jpg"]
                     },
          "Japan": {"Tokyo Dome": ["Tokyo, Japan", 
                                   "https://vignette.wikia.nocookie.net/prowrestling/images/b/bf/Tokyo_Dome.jpg"],
                    "Korakuen Hall": ["Tokyo, Japan", 
                                      "https://vignette.wikia.nocookie.net/prowrestling/images/6/64/Korakuen_Hall.jpg"],
                    "Budokan": ["Tokyo, Japan", 
                                "https://upload.wikimedia.org/wikipedia/commons/thumb/7/73/Nippon_Budokan_2010.jpg/250px-Nippon_Budokan_2010.jpg"],
                    "Ryōgoku Sumo Hall": ["Tokyo, Japan", 
                                          "https://upload.wikimedia.org/wikipedia/commons/thumb/c/c2/Ryogoku_Great_Sumo_Hall.jpg/300px-Ryogoku_Great_Sumo_Hall.jpg"]
                   },
          "Mexico": {"Arena México": ["Mexico City, Mexico", 
                                      "https://vignette.wikia.nocookie.net/prowrestling/images/1/18/Arena_M%C3%A9xico.jpg"],
                     "Arena Ciudad de México": ["Mexico City, Mexico", 
                                                "https://vignette.wikia.nocookie.net/prowrestling/images/0/04/Arena_Ciudad_de_M%C3%A9xico.JPG"]
                    },
          "USA": {"Madison Square Garden": ["Manhattan, NY, USA", 
                                            "https://vignette.wikia.nocookie.net/prowrestling/images/f/f7/MSG.jpg"],
                  "Barclays Center": ["Brooklyn, NY, USA", 
                                      "https://vignette.wikia.nocookie.net/prowrestling/images/3/32/Barclays_Center.png"],
                  "2300 Arena": ["Philadelphia, PA, USA", 
                                 "https://vignette.wikia.nocookie.net/prowrestling/images/a/a6/ECW_Arena.jpg"],
                  "Alamodome": ["San Antonio, TX, USA", 
                                "https://vignette.wikia.nocookie.net/prowrestling/images/6/6a/Alamodome.JPG"],
                  "Allstate Arena": ["Rosemont, Illinois", 
                                     "https://vignette.wikia.nocookie.net/prowrestling/images/1/1a/Allstate_Arena.jpg"],
                  "AT&T Stadium": ["Arlington, TX, USA", 
                                   "https://vignette.wikia.nocookie.net/prowrestling/images/a/ad/AT_%26_T_Stadium.JPG"],
                  "Cow Palace": ["Daly City, CA, USA", 
                                 "https://vignette.wikia.nocookie.net/prowrestling/images/5/56/Cow_Palace.jpg"],
                  "Hammerstein Ballroom": ["New York City, NY, USA", 
                                           "https://vignette.wikia.nocookie.net/prowrestling/images/c/cd/Hammerstein_Ballroom.jpg"],
                  "Mercedes-Benz Superdome": ["New Orleans, LA, USA", 
                                              "https://vignette.wikia.nocookie.net/prowrestling/images/e/ec/Louisiana_Superdome.jpg"],
                  "Met Life Stadium": ["East Rutherford, NJ, USA", 
                                       "https://vignette.wikia.nocookie.net/prowrestling/images/c/c3/Met_Life_Stadium.jpg"],
                  "Full Sail University": ["Winter Park, FL, USA", 
                                           "https://vignette.wikia.nocookie.net/prowrestling/images/4/4c/NXT_Arena.jpg/revision/latest?cb=20140816060330"],
                  "Staples Center": ["Los Angeles, CA, USA", 
                                     "https://vignette.wikia.nocookie.net/prowrestling/images/6/63/800px-Staples_Center%2C_LA%2C_CA%2C_jjron_22.03.2012.jpg"],
                  "Walter Pyramid": ["Long Beach, CA, USA", 
                                     "https://vignette.wikia.nocookie.net/prowrestling/images/c/c3/Walter_Pyramid.jpg"]
                 }
         }

objects =  ["Judy Bagwell", "Contract", "Guitar", "Kendo Stick", "Barbed Wire Bat",
            "Pianist", "Viagra", "Pole", "Dominic", "Autographed Jeff Jarrett Guitar",
            "JTG's Floppy Disk", "Lockbox", "Pickle", "Seasalted Caramel Chocolate",
            "Steroid Syringe", "Brass Knuckles", "Steel Chair", "Singapore Cane",
            'Contract With The Right To Say "Vince McMahon"', "Paddle", "Necklace",
            "Mistletoe", "Batista's Nose Ring", "Bucket Of Broken Chicken Necks",
            "placeholder", "La Bestia del Ring Triple Singh IV"
           ]

cardnames = ["Wrestlerama", "Wrestlepalooza", "WrestleWorld", 
             "Well It's A Big Show", "Wrestling Empire", "Endgame", 
             "Wrestling Summit", "Global Wars", "Wrestle Fest", 
             "War Of The Worlds", "Wrestleverse", "Wrestling Universe",
             "Final Battle", "Wrestle War", "Wrestlepex", "Wrestle Sesh", 
             "Wrestlympics", "Rumble in the Jungle", "Wrestival", 
             "Wrestling Classic", "The Final Showdown", "On The Line", 
             "Wrestlection", "Final Destination", "Wrestlympiad", 
             "World Series Of Wrestling", "Wrestle Rally", "Wrestling World", 
             "Back To The Future 2"
            ]

tagmoves = [
            "Magic Killer", "Power-Plex", "Rocket Launcher", "Death Drop",
            "Total Elimination", "Flapjack DDT", "Doomsday Device", "Event Omega",
            "Double Chokeslam", "Double DDT", "Double Dropkick", "Double Elbow Drop",
            "Double Superkick", "Sky Lift Slam", "Double Spanish Fly",
            "Wishbone", "4:20 Double Leg Drop", "Meeting Of The Minds"
            ]

past_titles = {"Jake Lee": ["AJPW All Asia Tag Team Championship", "AJPW World Tag Team Championship"],
               "Shuji Ishikawa": ["KO-D Openweight Championship (x4)", "KO-D Tag Team Championship", "AJPW World Tag Team Championship (x2)", "DDT Extreme Championship", "AJPW Triple Crown Championship"],
               "Suwama": ["AJPW Triple Crown Championship (x6)", "AJPW World Tag Team Championship (x3)"],
               "BxB Hulk": ["GHC Junior Heavyweight Tag Team Championship", "Open The Dream Gate Championship", "Open The Twin Gate Championship (x5)"],
               "Rey Mysterio": ["WWE Championship", "WWE Intercontinental Championship (x2)", "WWE RAW Tag Team Championship (x4)", "WWE United States Championship"],
               "Brock Lesnar": ["WWE Universal Championship (x2)", "WWE Championship (x4)", "IWGP Heavyweight Championship"],
               "Yoshitatsu": ["AJPW World Tag Team Championship"],
               "Kento Miyahara": ["AJPW Triple Crown Championship (x3)", "AJPW World Tag Team Championship (x2)", "AJPW All Asia Tag Team Championship"],
               "Go Shiozaki": ["AJPW Triple Crown Championship", "GHC Heavyweight Championship (x3)", "GHC Tag Team Championship (x7)", "AJPW World Tag Team Championship (x2)"],
               "Katsuhiko Nakajima": ["AJPW World Junior Heavyweight Championship", "AJPW All Asia Tag Team Championship", "GHC Heavyweight Championship", "GHC Junior Heavyweight Championship (x3)", "GHC Tag Team Championship (x5)"],
               "Kofi Kingston": ["WWE RAW Tag Team Championship (x4)", "WWE Intercontinental Championship (x4)", "WWE SmackDown Tag Team Championship (x3)", "WWE United States Championship (x3)"],
               "Xavier Woods": ["WWE RAW Tag Team Championship (x2)", "WWE SmackDown Tag Team Championship (x3)", "Impact World Tag Team Championship"],
               "Jay Lethal": ["Impact World Tag Team Championship", "Impact X Division Championship (x6)", "ROH World Championship (x2)", "ROH World Television Championship (x2)"],
               "Susumu Yokosuka": ["Open The Dream Gate Championship (x2)", "Open The Twin Gate Championship (x6)"],
               "Genki Horiguchi": ["Open The Brave Gate Championship (x2)", "Open The Twin Gate Championship (x2)"],
               "Kaito Kiyomiya": ["GHC Tag Team Championship"],
               "Konosuke Takeshita": ["KO-D Openweight Championship (x3)", "KO-D Tag Team Championship (x3)"],
               "Akito": ["DDT Extreme Championship (x3)"],
               "Hirooki Goto": ["NEVER Openweight Championship (x4)", "IWGP Tag Team Championship", "IWGP Junior Heavyweight Tag Team Championship", "IWGP Intercontinental Championship (x2)"],
               "CIMA": ["Open The Dream Gate Championship (x3)", "Open The Brave Gate Championship", "Open The Twin Gate Championship (x5)"],
               "Ricochet": ["IWGP Junior Heavyweight Tag Team Championship (x3)", "Open The Brave Gate Championship", "Open The Dream Gate Championship", "Open The Twin Gate Championship (x2)", "NXT North American Championship", "WWE United States Championship"],
               "Hiroshi Tanahashi": ["IWGP Heavyweight Championship (x8)", "GHC Tag Team Championship", "IWGP Intercontinental Championship (x2)", "IWGP Tag Team Championship (x2)"],
               "Shinsuke Nakamura": ["IWGP Heavyweight Championship (x3)", "IWGP Intercontinental Championship (x5)", "IWGP Tag Team Championship", "NXT Championship", "WWE United States Championship (x2)"],
               "Yosuke:heart:Santa Maria": ["Open The Brave Gate Championship"],
               "Ben-K": ["Open The Twin Gate Championship (x2)"],
               "Juice Robinson": ["IWGP United States Heavyweight Championship (x2)"],
               "Jon Moxley": ["WWE Championship", "WWE Intercontinental Championship (x3)", "WWE RAW Tag Team Championship (x2)", "WWE United States Championship"],
               "Seth Rollins": ["ROH World Championship", "ROH World Tag Team Championship (x2)", "WWE Championship (x2)", "WWE Intercontinental Championship (x2)", "NXT Championship", "WWE RAW Tag Team Championship (x4)", "WWE United States Championship", "WWE Universal Championship"],
               "Roman Reigns": ["WWE Championship (x3)", "WWE Intercontinental Championship", "WWE RAW Tag Team Championship", "WWE United States Championship", "WWE Universal Championship"],
               "Tomohiro Ishii": ["IWGP Tag Team Championship", "NEVER Openweight Championship (x5)", "ROH World Television Championship"],
               "Toru Yano": ["IWGP Tag Team Championship (x3)", "GHC Tag Team Championship (x2)"],
               "Naomichi Marufuji": ["AJPW World Junior Heavyweight Championship", "GHC Heavyweight Championship (x3)", "GHC Junior Heavyweight Championship", "GHC Junior Heavyweight Tag Team Championship (x2)", "GHC Tag Team Championship (x6)", "IWGP Junior Heavyweight Championship", "KO-D Tag Team Championship"],
               "Takashi Sugiura": ["GHC Heavyweight Championship (x4)", "GHC Junior Heavyweight Championship (x2)", "GHC Junior Heavyweight Tag Team Championship (x2)", "GHC Tag Team Championship (x5)"]
               }

legends = ["Ric Flair", "Jerry Lawler", "Antonio Inoki", "Booker T", "Stan Hansen", "Jeff Jarrett", "Edge", "Hulk Hogan", "Sting", "Bret Hart", "Steve Austin",
           "Kensuke Sasaki", "Kevin Nash", "The Rock", "Shawn Michaels", "Kenta Kobashi", "Toshiaki Kawada", "Manami Toyota", "Ricky Steamboat", "D-Von Dudley",
           "Bull Nakano", "Christian", "Scott Hall", "Riki Choshu", "Terry Funk", "Mick Foley", "Masahiro Chono", "CM Punk", "William Regal", "Batista", 
           "Diamond Dallas Page", "Akira Taue", "Trish Stratus", "Atsushi Onita"
          ]

wrestlers_master = []
for k, v in wrestlers.items():
  wrestlers_master.extend(v)
fem_master = []
for k, v in women.items():
  fem_master.extend(v)
me_master = []
for k, v in maineventers.items():
  me_master.extend(v)
tag_master = {}
for k, v in tagteams.items():
  tag_master.update(v)
title_master = {}
for k, v in titles.items():
  title_master.update(v)
venue_master = {}
for k, v in venues.items():
  venue_master.update(v)
stable_master = {}
for k, v in stables.items():
  stable_master.update(v)
factionbois = []
for k, v in stable_master.items():
  factionbois.extend(v)

all_wrestlers = wrestlers_master + fem_master
  
metitles = []
midtitles = []
tagtitles = []
femtitles = []
for k, v in title_master.items():
  if (v[1] == "ME"):
    metitles.append(k)
  elif (v[1] == "MID"):
    midtitles.append(k)
  elif (v[1] == "TAG"):
    tagtitles.append(k)
  elif (v[1] == "W"):
    femtitles.append(k)
MAX_PROB = 50


matchresults = {"header": "",
                "first": [],
                "second": [],
                "fem": [],
                "tag": [],
                "mg": [],
                "MID": [],
                "ME": []
               }

winloss = {}

def checkteams(team, faction, tag):
  inateam = []
  for w in team:
    for k, v in tag_master.items():
      tagtime = []
      if w in v and w not in inateam:
        if k == faction:
          break
        tagtime = v
        for t in tagtime:
          if t in team and t != w:
            if len(tagtime) > 2:
              tag.append(k + " ({} & {})".format(w, t))
            else:
              tag.append(k)
            inateam.extend([w,t])
            print(team, inateam)
            break
  [team.remove(x) for x in inateam]

# %%
@client.event
async def on_message(message):
  # we do not want the bot to reply to itself
  if message.author == client.user:
    return
  
  if message.content.startswith('!hello'):
    msg = 'Hello {0.author.mention}'.format(message)
    msg += "\nNumber of wrestlers in the DB: {}".format(len(wrestlers_master) + len(fem_master))
    msg += "\nNumber of male wrestlers: {}".format(len(wrestlers_master))
    msg += "\nNumber of female wrestler: {}".format(len(fem_master))
    await client.send_message(message.channel, msg)
    print(message.author.mention)
    
  if message.content.startswith("!fbhelp"):
    embed=discord.Embed(title="Commands", description="These are the commands of the FantasyBookers bot")
    embed.add_field(name="random1v1", value="Generates a random singles match between two wrestlers")
    embed.add_field(name="random2v2", value="Generates a random tag team match between two teams, either an established tag team or two random wresters")
    embed.add_field(name="randommulti", value="Generates a random multi-man match with teams of size 3-5, entirely random")
    embed.add_field(name="randomcard", value="Generates a random supercard, with a 8-10 man match, a 6-man match, a womens title match, a tag title match, a gimmick match or midcard title match, a midcard title match and a main event match")
    embed.add_field(name="randomintergender", value="Generates a random intergender tag match")
    embed.add_field(name="caw", value="Generates a random name, perfect for creating a generic wrestler")
    embed.add_field(name="results", value="Generates results for the most recently generated random card, along with title changes")
    embed.add_field(name="titles", value="Displays the titles of a promotion, a wrestler or a tag team depending on the parameter")
    embed.add_field(name="roster", value="Displays the detailed roster of the selected promotion")
    embed.add_field(name="faction", value="Displays the details of a selected faction")
    embed.add_field(name="winloss", value="Displays the top 5 wrestlers with the best win/loss ratio. Adding a wrestler's name shows their personal win/loss record, and adding streak to the end of the command shows the wrestlers with the currenmt longest streak")
    embed.add_field(name="info", value="Displays information about the chosen wrestler, with tag, faction and title info")
    embed.add_field(name="rumble", value="Simulates an intergender Rumble match. Usage: !rumble [size] (m or f)")
    embed.add_field(name="fbhelp", value="Displays all of the commands that are available with this bot")
    embed.set_footer(text="This help embed was brought to you by the Devil Cyborg corporation")
    await client.send_message(message.channel,"",embed=embed)
    
  if message.content.startswith("!caw"):
    prob = random.randint(0,100)
    name = random.choice(firstnames) + " " + random.choice(lastnames)
    if prob < 80 and prob >= 70:
      name = random.choice(startnick) + " " + name
    elif prob < 90 and prob >= 80:
      name = random.choice(startnick) + " " + name + " " + random.choice(endnick)
    elif prob >= 90:
      name = name + " " + random.choice(endnick)
    await client.send_message(message.channel, name)
    
  if message.content.startswith('!random1v1'):
    prob = random.randint(0,100)
    wrestler1 = random.choice(wrestlers_master)
    wrestler2 = random.choice(wrestlers_master)
    while (wrestler1 == wrestler2):
      wrestler2 = random.choice(wrestlers_master)
    fed1 = ""
    fed2 = ""
    feds1 = []
    feds2 = []
    for k,v in wrestlers.items():
      if wrestler1 in v:
        feds1.append(k.upper())
      if wrestler2 in v:
        feds2.append(k.upper())
    if len(feds1) > 1:
      if len(feds1) > 2:
        fed1 = "{}/{}/{}".format(feds1[0], feds1[1], feds1[2])
      else:
        fed1 = "{}/{}".format(feds1[0], feds1[1])
    else:
      fed1 = feds1[0]
    if len(feds2) > 1:
      if len(feds2) > 2:
        fed2 = "{}/{}/{}".format(feds2[0], feds2[1], feds2[2])
      else:
        fed2 = "{}/{}".format(feds2[0], feds2[1])
    else:
      fed2 = feds2[0] 
        
    if prob < MAX_PROB:
      if ((fed1 != "" and fed2 != "") and fed1 != fed2):
        msg = "{} ({}) vs {} ({})".format(wrestler1, fed1, wrestler2, fed2)
      else:
        msg = "{} vs {}".format(wrestler1, wrestler2)
    else:
      prob = random.randint(0,100)
      if prob < 90:
        gimmick = random.choice(gimmickmatches)
        while gimmick == "{} On A Pole Match":
          gimmick = random.choice(gimmickmatches)
      else:
        obj = random.choice(objects)
        if obj == "placeholder":
          obj = message.author.mention
        gimmick = "{} On A Pole Match".format(obj)
      if ((fed1 != "" and fed2 != "") and fed1 != fed2):
        msg = "**{}**\n{} ({}) vs {} ({})".format(gimmick, wrestler1, fed1, wrestler2, fed2)
      else:
        msg = "**{}**\n{} vs {}".format(gimmick, wrestler1, wrestler2)
    await client.send_message(message.channel, msg)
    
  if message.content.startswith("!randomintergender"):
    wrestler1 = random.choice(wrestlers_master)
    wrestler2 = random.choice(wrestlers_master)
    while wrestler1 == wrestler2:
      wrestler2 = random.choice(wrestlers_master)
    woman1 = random.choice(fem_master)
    woman2 = random.choice(fem_master)
    while woman1 == woman2:
      woman2 = random.choice(fem_master)
    team1 = "{} & {}".format(wrestler1, woman1)
    team2 = "{} & {}".format(wrestler2, woman2)
    msg = "{} vs {}".format(team1, team2)
    await client.send_message(message.channel, msg)
    
  if message.content.startswith("!randomgimmick"):
    print("gimmick match starting")
    wrestler1 = random.choice(wrestlers_master)
    wrestler2 = random.choice(wrestlers_master)
    while (wrestler1 == wrestler2):
      wrestler2 = random.choice(wrestlers_master)
    fed1 = ""
    fed2 = ""
    feds1 = []
    feds2 = []
    for k,v in wrestlers.items():
      if wrestler1 in v:
        feds1.append(k.upper())
      if wrestler2 in v:
        feds2.append(k.upper())
    if len(feds1) > 1:
      if len(feds1) > 2:
        fed1 = "{}/{}/{}".format(feds1[0], feds1[1], feds1[2])
      else:
        fed1 = "{}/{}".format(feds1[0], feds1[1])
    else:
      fed1 = feds1[0]
    if len(feds2) > 1:
      if len(feds2) > 2:
        fed2 = "{}/{}/{}".format(feds2[0], feds2[1], feds2[2])
      else:
        fed2 = "{}/{}".format(feds2[0], feds2[1])
    else:
      fed2 = feds2[0] 
    prob = random.randint(0,100)
    if prob >= MAX_PROB:
      gimmick = random.choice(gimmickmatches)
      obj = random.choice(objects)
      if obj == "placeholder":
        obj = message.author.mention
      gimmick.format(obj)
    else:
      obj = random.choice(objects)
      if obj == "placeholder":
        obj = message.author.mention
      gimmick = "{} On A Pole Match".format(obj)
    if ((fed1 != "" and fed2 != "") and fed1 != fed2):
      msg = "**{}**\n{} ({}) vs {} ({})".format(gimmick, wrestler1, fed1, wrestler2, fed2)
    else:
      msg = "**{}**\n{} vs {}".format(gimmick, wrestler1, wrestler2)
    await client.send_message(message.channel, msg)

  #generates a random tag team match
  if message.content.startswith("!random2v2"):
    
    fed1 = ""
    fed2 = ""
    
    prob = random.randint(0,100)
    if (prob < 70):
      tagteam1 = random.choice(list(tag_master.keys()))
      for k, v in tagteams.items():
        if tagteam1 in list(v.keys()):
          fed1 = k
      wrestler11 = random.choice(tag_master[tagteam1][0])
      wrestler12 = random.choice(tag_master[tagteam1][1])
      while (wrestler11 == wrestler12):
        wrestler12 = random.choice(tag_master[tagteam1])
      if (len(tag_master[tagteam1]) > 2):
        wrestler11 = random.choice(tag_master[tagteam1])
        wrestler12 = random.choice(tag_master[tagteam1])
        while (wrestler11 == wrestler12):
          wrestler12 = random.choice(tag_master[tagteam1])
        tagteam1 = tagteam1 + " ({} & {})".format(wrestler11, wrestler12)
      
    else:
      fed1 = random.choice(list(wrestlers.keys()))
      wrestler11 = random.choice(wrestlers[fed1])
      wrestler12 = random.choice(wrestlers[fed1])
      while (wrestler11 == wrestler12):
        wrestler12 = random.choice(wrestlers[fed1])
      tagteam1 = "{} & {}".format(wrestler11, wrestler12)
      
    prob = random.randint(0,100)
    if (prob < 70):
      tagteam2 = random.choice(list(tag_master.keys()))
      for k, v in tagteams.items():
        if tagteam2 in list(v.keys()):
          fed2 = k
      wrestler21 = random.choice(tag_master[tagteam2])
      wrestler22 = random.choice(tag_master[tagteam2])
      while (wrestler21 == wrestler22):
        wrestler22 = random.choice(tag_master[tagteam2])
      if (len(tag_master[tagteam2]) > 2):
        wrestler21 = random.choice(tag_master[tagteam2])
        wrestler22 = random.choice(tag_master[tagteam2])
        while (wrestler21 == wrestler22):
          wrestler22 = random.choice(tag_master[tagteam2])
        tagteam2 = tagteam2 + " ({} & {})".format(wrestler21, wrestler22)
    else:
      fed2 = random.choice(list(wrestlers.keys()))
      wrestler21 = random.choice(wrestlers[fed2])
      wrestler22 = random.choice(wrestlers[fed2])
      while (wrestler21 == wrestler22):
        wrestler22 = random.choice(wrestlers[fed2])
      tagteam2 = "{} & {}".format(wrestler21, wrestler22)
    while(tagteam1 == tagteam2 or wrestler11 == wrestler21 or wrestler12 == wrestler22 or
          wrestler11 == wrestler22 or wrestler12 == wrestler21):
      prob = random.randint(0,100)
      if (prob < 70):
        tagteam2 = random.choice(list(tag_master.keys()))
        for k, v in tagteams.items():
          if tagteam2 in list(v.keys()):
            fed2 = k
        wrestler21 = random.choice(tag_master[tagteam2])
        wrestler22 = random.choice(tag_master[tagteam2])
        if (len(tag_master[tagteam2]) > 2):
          wrestler21 = random.choice(tag_master[tagteam2])
          wrestler22 = random.choice(tag_master[tagteam2])
          while (wrestler21 == wrestler22):
            wrestler22 = random.choice(tag_master[tagteam2])
          tagteam2 = tagteam2 + " ({} & {})".format(wrestler21, wrestler22)
      else:
        fed2 = random.choice(list(wrestlers.keys()))
        wrestler21 = random.choice(wrestlers[fed2])
        wrestler22 = random.choice(wrestlers[fed2])
        while (wrestler21 == wrestler22):
          wrestler22 = random.choice(wrestlers[fed2])
        tagteam2 = "{} & {}".format(wrestler21, wrestler22)
    if fed1 != fed2:
      msg = "{} ({}) vs {} ({})".format(tagteam1, fed1.upper(), tagteam2, fed2.upper())
    else:
      msg = "{} vs {}".format(tagteam1, tagteam2)
    await client.send_message(message.channel, msg)
    
  if message.content.startswith("!randommulti"):
    TEAM_SIZE = random.randint(3,5)
    fed1 = random.choice(list(wrestlers.keys()))
    wrestlers1 = []
    for i in range(TEAM_SIZE):
        if not wrestlers1:
          wrestlers1.append(random.choice(wrestlers[fed1]))
        else:
          wrestler12 = random.choice(wrestlers[fed1])
          while (wrestler12 in wrestlers1):
            wrestler12 = random.choice(wrestlers[fed1])
          wrestlers1.append(wrestler12)
    wrestlers2 = []
    fed2 = random.choice(list(wrestlers.keys()))
    for i in range(TEAM_SIZE):
        if not wrestlers2:
          wrestlers2.append(random.choice(wrestlers[fed2]))
        else:
          wrestler22 = random.choice(wrestlers[fed2])
          while (wrestler22 in wrestlers2):
            wrestler22 = random.choice(wrestlers[fed2])
          wrestlers2.append(wrestler22)
    if (TEAM_SIZE == 3):
      msg = "{}, {} & {} ({}) vs {}, {} & {} ({})".format(wrestlers1[0], wrestlers1[1],
                                                          wrestlers1[2], fed1.upper(), wrestlers2[0],
                                                          wrestlers2[1], wrestlers2[2], fed2.upper())
    if (TEAM_SIZE == 4):
      msg = "{}, {}, {} & {} ({}) vs {}, {}, {} & {} ({})".format(wrestlers1[0], wrestlers1[1],
                                                        wrestlers1[2], wrestlers1[3], fed1.upper(),
                                                        wrestlers2[0], wrestlers2[1],
                                                        wrestlers2[2], wrestlers2[3], fed2.upper())
    if (TEAM_SIZE == 5):
      msg = "{}, {}, {}, {} & {} ({}) vs {}, {}, {}, {} & {} ({})".format(wrestlers1[0], wrestlers1[1],
                                                                wrestlers1[2], wrestlers1[3], 
                                                                wrestlers1[4], fed1.upper(),
                                                                wrestlers2[0], wrestlers2[1],
                                                                wrestlers2[2], wrestlers2[3],
                                                                wrestlers2[4], fed2.upper())
      
    await client.send_message(message.channel, msg)
    
  if message.content.startswith("!randomcard"):
    
    venue = random.choice(list(venue_master.keys()))
    attendance = random.randint(1000,100000)
    cardname = random.choice(cardnames)
    header = "**Live From {}, In {}, Welcome To {}!**\n*Attendance: {:,} people*\n\n".format(venue_master[venue][0], venue, cardname, attendance)
    e.set_image(url=venue_master[venue][1])
    matchresults["header"] = "__{} Results__\n".format(cardname)
    
    prob = random.randint(0,100)
    usedwrestlers = []
    metitle = random.choice(metitles)
    midtitle = random.choice(midtitles)
    if (prob < 50):
      midorgimmick = "mid"
      midtitle2 = random.choice(midtitles)
      while (midtitle2 == midtitle):
        midtitle2 = random.choice(midtitles)
    else:
      midorgimmick = "gimmick"
      prob = random.randint(0,100)
      if prob >= 70:
        obj = random.choice(objects)
        if obj == "placeholder":
          obj = message.author.mention
        gimmick = "{} On A Pole Match".format(obj)
      else:
        gimmick = random.choice(gimmickmatches)
        obj = random.choice(objects)
        if obj == "placeholder":
          obj = message.author.mention
        gimmick.format(obj)
    usedwrestlers.extend([title_master[metitle][0], title_master[midtitle][0]])
    if midorgimmick == "mid":
      usedwrestlers.append(title_master[midtitle2][0])
    tagtitle = random.choice(tagtitles)
    print("Champion = " + ", ".join(tag_master[title_master[tagtitle][0]]))
    print("Title = " + tagtitle)
    while tag_master[title_master[tagtitle][0]][0] in usedwrestlers or tag_master[title_master[tagtitle][0]][1] in usedwrestlers:
      tagtitle = random.choice(tagtitles)
    femtitle = random.choice(femtitles)
    
    usedwrestlers.extend([tag_master[title_master[tagtitle][0]][0], tag_master[title_master[tagtitle][0]][1], title_master[femtitle][0]])
    
      
    fed1 = ""
    fed2 = ""
    
    champion = title_master[metitle][0]
    challenger = random.choice(me_master)
    while (challenger == champion or challenger in usedwrestlers):
      challenger = random.choice(me_master)
    mematch = "**{}**\n{} (c) vs {}".format(metitle, champion, challenger)
    usedwrestlers.append(challenger)
    matchresults["ME"] = [metitle, champion, challenger]
    
    champion = title_master[midtitle][0]
    challenger = random.choice(wrestlers_master)
    while (challenger == champion or challenger in usedwrestlers):
      challenger = random.choice(wrestlers_master)
    midmatch = "**{}**\n{} (c) vs {}\n\n".format(midtitle, champion, challenger)
    usedwrestlers.append(challenger)
    matchresults["MID"] = [midtitle, champion, challenger]
    
    head = ""
    if midorgimmick == "mid":
      champion = title_master[midtitle2][0]
      challenger = random.choice(wrestlers_master)
      while (challenger == champion or challenger in usedwrestlers):
        challenger = random.choice(wrestlers_master)
      midmatch2 = "**{}**\n{} (c) vs {}\n\n".format(midtitle2, champion, challenger)
      usedwrestlers.append(challenger)
      head = midtitle2
      wrestler1 = champion
      wrestler2 = challenger
    elif midorgimmick == "gimmick":
      wrestler1 = random.choice(wrestlers_master)
      while wrestler1 in usedwrestlers:
        wrestler1 = random.choice(wrestlers_master)
      wrestler2 = random.choice(wrestlers_master)
      while (wrestler1 == wrestler2 or wrestler2 in usedwrestlers):
        wrestler2 = random.choice(wrestlers_master)
      midmatch2 = "**{}**\n{} vs {}\n\n".format(gimmick, wrestler1, wrestler2)
      usedwrestlers.extend([wrestler1, wrestler2])
      head = gimmick
    matchresults["mg"] = [head, wrestler1, wrestler2]
    
    champion = title_master[tagtitle][0]
    prob = random.randint(1,100)
    if prob <= 80:
      challenger = random.choice(list(tag_master.keys()))
      print("Challenger = " + challenger)
      while (list(tag_master[challenger])[0] in usedwrestlers or list(tag_master[challenger])[1] in usedwrestlers):
        challenger = random.choice(list(tag_master.keys()))
      challengerog = challenger
      if len(tag_master[challenger]) > 2:
        wrestler1 = random.choice(tag_master[challenger])
        wrestler2 = random.choice(tag_master[challenger])
        while (wrestler1 == wrestler2):
          wrestler2 = random.choice(tag_master[challenger])
        challenger = challenger + " ({} & {})".format(wrestler1, wrestler2)
      while (challenger == champion):
        challenger = random.choice(list(tag_master.keys()))
      if len(tag_master[challengerog]) > 2:
        usedwrestlers.extend([wrestler1, wrestler2])
      else:
        usedwrestlers.extend([tag_master[challenger][0], tag_master[challenger][1]])
    else:
      fed = random.choice(list(wrestlers.keys()))
      pit = []
      for t, d in tag_master.items():
        pit.extend(d)
      challenger1 = random.choice(wrestlers[fed])
      while challenger1 in pit:
        challenger1 = random.choice(wrestlers[fed])
      challenger2 = random.choice(wrestlers[fed])
      while challenger1 == challenger2 or challenger2 in pit:
        challenger2 = random.choice(wrestlers[fed])
      challenger = "{} & {}".format(challenger1, challenger2)
      tag_master[challenger] = [challenger1, challenger2]
      usedwrestlers.extend(challenger.split(" & "))
      finishers[challenger] = random.choice(tagmoves)
      
    tagmatch = "**{}**\n{} (c) vs {}\n\n".format(tagtitle, champion, challenger)
    
    matchresults["tag"] = [tagtitle, champion, challenger]
    
    champion = title_master[femtitle][0]
    prob = random.randint(0,100)
    challengers = []
    if prob < 70:
      # 1 vs 1
      challenger = random.choice(fem_master)
      while(challenger == champion):
        challenger = random.choice(fem_master)
      femmatch = "**{}**\n{} (c) vs {}\n\n".format(femtitle, champion, challenger)
      usedwrestlers.append(challenger)
    else:
      r = random.randint(2,3)
      for i in range(r):
        challenger = random.choice(fem_master)
        while challenger in challengers or challenger in usedwrestlers or challenger == champion:
          challenger = random.choice(fem_master)
        challengers.append(challenger)
      if (r == 2):
        femmatch = "**{}**\n{} (c) vs {} vs {}\n\n".format(femtitle, champion, challengers[0], challengers[1])
      if r == 3:
        femmatch = "**{}**\n{} (c) vs {} vs {} vs {}\n\n".format(femtitle, champion, challengers[0], challengers[1], challengers[2])
      usedwrestlers.extend(challengers)
    matchresults["fem"] = [femtitle, champion]
    if not challengers:
      matchresults["fem"].append(challenger)
    else:
      matchresults["fem"].extend(challengers)
    
        
    
    TEAM_SIZE = random.randint(4,5)
    team1 = []
    team2 = []
    tag1 = []
    tag2 = []
    fed1 = ""
    fed2 = ""
    faction1 = ""
    faction2 = ""
    teams = []
    fitSize = []
    for k, v in stable_master.items():
      if len(v) >= TEAM_SIZE:
        fitSize.append(k)
        
    prob = random.randint(0,100)
    dec = 0
    if prob < 70:
      faction1 = random.choice(fitSize)
      for w in usedwrestlers:
        if w in stable_master[faction1]:
          dec -= 1
      while (len(stable_master[faction1]) + dec) < TEAM_SIZE:
        dec = 0
        faction1 = random.choice(fitSize)
        for w in usedwrestlers:
          if w in stable_master[faction1]:
            dec -= 1
    else:
      fed1 = random.choice(list(wrestlers.keys()))
      
    prob = random.randint(0,100)
    dec = 0
    if prob < 70:
      faction2 = random.choice(fitSize)
      while (faction1 == faction2 or (faction1 == "Lifeblood" and faction2 == "Taguchi Japan")
            or (faction2 == "Lifeblood" and faction1 == "Taguchi Japan")):
        faction2 = random.choice(fitSize)
      for w in usedwrestlers:
        if w in stable_master[faction2]:
          dec -= 1
      while (len(stable_master[faction2]) + dec) < TEAM_SIZE:
        dec = 0
        faction2 = random.choice(fitSize)
        for w in usedwrestlers:
          if w in stable_master[faction2]:
            dec -= 1
    else:
      fed2 = random.choice(list(wrestlers.keys()))
    for i in range(TEAM_SIZE):
      if not team1:
        if fed1 == "":
          if len(stable_master[faction1]) == TEAM_SIZE:
            team1.extend(stable_master[faction1])
          else:
            wrestler = random.choice(stable_master[faction1])
            while wrestler in usedwrestlers:
                wrestler = random.choice(stable_master[faction1])
            team1.append(wrestler)
        else:
          wrestler = random.choice(wrestlers[fed1])
          while wrestler in usedwrestlers or wrestler in factionbois:
            wrestler = random.choice(wrestlers[fed1])
          team1.append(wrestler)
      elif len(team1) == TEAM_SIZE:
        pass
      else:
        if fed1 == "":
          wrestler = random.choice(stable_master[faction1])
          while wrestler in usedwrestlers or wrestler in team1 or wrestler in team2:
            wrestler = random.choice(stable_master[faction1])
        else:
          wrestler = random.choice(wrestlers[fed1])
          while wrestler in usedwrestlers or wrestler in team1 or wrestler in team2 or wrestler in factionbois:
            wrestler = random.choice(wrestlers[fed1])
        team1.append(wrestler)
        
      if not team2:
        if fed2 == "":
          if len(stable_master[faction2]) == TEAM_SIZE:
            team2.extend(stable_master[faction2])
          else:
            wrestler = random.choice(stable_master[faction2])
            while wrestler in usedwrestlers:
              wrestler = random.choice(stable_master[faction2])
            team2.append(wrestler)
        else:
          wrestler = random.choice(wrestlers[fed2])
          while wrestler in usedwrestlers or wrestler in factionbois:
            wrestler = random.choice(wrestlers[fed2])
          team2.append(wrestler)
      elif len(team2) == TEAM_SIZE:
        pass
      else:
        if fed2 == "":
          wrestler = random.choice(stable_master[faction2])
          while wrestler in usedwrestlers or wrestler in team1 or wrestler in team2:
            wrestler = random.choice(stable_master[faction2])
        else:
          wrestler = random.choice(wrestlers[fed2])
          while wrestler in usedwrestlers or wrestler in team1 or wrestler in team2 or wrestler in factionbois:
            wrestler = random.choice(wrestlers[fed2])
        team2.append(wrestler)
                  
    checkteams(team1, faction1, tag1)
    checkteams(team2, faction2, tag2)
        
    if (TEAM_SIZE == 4):
      if not tag1:
        if fed1 == "":
            teams.append("{} ({}, {}, {} & {})".format(faction1,team1[0],team1[1],team1[2],team1[3]))
        else:
            teams.append("{}, {}, {} & {} ({})".format(team1[0],team1[1],team1[2],team1[3], fed1.upper()))
      elif len(tag1) == 1:
        if fed1 == "":
          if "&" in tag1[0]:
            teams.append("{} ({}, {}, {})".format(faction1,team1[0],team1[1],tag1[0]))
          else:
            teams.append("{} ({}, {} & {})".format(faction1,team1[0],team1[1],tag1[0]))
        else:
          if "&" in tag1[0]:
            teams.append("{}, {}, {} ({})".format(team1[0],team1[1], tag1[0], fed1.upper()))
          else:
            teams.append("{}, {} & {} ({})".format(team1[0],team1[1], tag1[0], fed1.upper()))
      elif len(tag1) == 2:
        if fed1 == "":
          if "&" in tag1[0]:
            if "&" in tag1[1]:
              teams.append("{} ({}, {})".format(faction1, tag1[0], tag1[1]))
            else:
              teams.append("{} ({}, {})".format(faction1, tag1[1], tag1[0]))
          else:
            if "&" in tag1[1]:
              teams.append("{} ({}, {})".format(faction1, tag1[0], tag1[1]))
            else:
              teams.append("{} ({} & {})".format(faction1, tag1[0], tag1[1]))
        else:
          if "&" in tag1[0]:
            if "&" in tag1[1]: 
              teams.append("{}, {} ({})".format(tag1[0], tag1[1], fed1.upper()))
            else:
              teams.append("{}, {} ({})".format(tag1[1], tag1[0], fed1.upper()))
          else:
            if "&" in tag1[1]:
              teams.append("{}, {} ({})".format(tag1[0], tag1[1], fed1.upper()))
            else:
              teams.append("{} & {} ({})".format(tag1[0], tag1[1], fed1.upper()))
        
      if not tag2:  
        if fed2 == "":
          teams.append("{} ({}, {}, {} & {})".format(faction2, team2[0],team2[1],team2[2],team2[3]))
        else:
          teams.append("{}, {}, {} & {} ({})".format(team2[0],team2[1],team2[2],team2[3], fed2.upper()))
      elif len(tag2) == 1:
        if fed2 == "":
          if "&" in tag2[0]:
            teams.append("{} ({}, {}, {})".format(faction2,team2[0],team2[1],tag2[0]))
          else:
            teams.append("{} ({}, {} & {})".format(faction2,team2[0],team2[1],tag2[0]))
        else:
          if "&" in tag2[0]:
            teams.append("{}, {}, {} ({})".format(team2[0],team2[1], tag2[0], fed2.upper()))
          else:
            teams.append("{}, {} & {} ({})".format(team2[0],team2[1], tag2[0], fed2.upper()))
      elif len(tag2) == 2:
        if fed2 == "":
          if "&" in tag2[0]:
            if "&" in tag2[1]:
              teams.append("{} ({}, {})".format(faction2, tag2[0], tag2[1]))
            else:
              teams.append("{} ({}, {})".format(faction2, tag2[1], tag2[0]))
          else:
            if "&" in tag2[1]:
              teams.append("{} ({}, {})".format(faction2, tag2[0], tag2[1]))
            else:
              teams.append("{} ({} & {})".format(faction2, tag2[0], tag2[1]))
        else:
          if "&" in tag2[0]:
            if "&" in tag2[1]: 
              teams.append("{}, {} ({})".format(tag2[0], tag2[1], fed2.upper()))
            else:
              teams.append("{}, {} ({})".format(tag2[1], tag2[0], fed2.upper()))
          else:
            if "&" in tag2[1]:
              teams.append("{}, {} ({})".format(tag2[0], tag2[1], fed2.upper()))
            else:
              teams.append("{} & {} ({})".format(tag2[0], tag2[1], fed2.upper()))
          
          
    elif (TEAM_SIZE == 5):
      if not tag1:
        if fed1 == "":
          teams.append("{} ({}, {}, {}, {} & {})".format(faction1,team1[0],team1[1],team1[2],team1[3], team1[4]))
        else:
          teams.append("{}, {}, {}, {} & {} ({})".format(team1[0],team1[1],team1[2],team1[3], team1[4], fed1.upper()))
      elif len(tag1) == 1:
        if fed1 == "":
          if "&" in tag1[0]:
            teams.append("{} ({}, {}, {}, {})".format(faction1,team1[0],team1[1], team1[2], tag1[0]))
          else:
            teams.append("{} ({}, {}, {} & {})".format(faction1,team1[0],team1[1], team1[2], tag1[0]))
        else:
          if "&" in tag1[0]:
            teams.append("{}, {}, {}, {} ({})".format(team1[0],team1[1], team1[2], tag1[0], fed1.upper()))
          else:
            teams.append("{}, {}, {} & {} ({})".format(team1[0],team1[1], team1[2], tag1[0], fed1.upper()))
      elif len(tag1) == 2:
        if fed1 == "":
          if "&" in tag1[0]:
            if "&" in tag1[1]:
              teams.append("{} ({}, {}, {})".format(faction1, team1[0], tag1[0], tag1[1]))
            else:
              teams.append("{} ({}, {}, {})".format(faction1, team1[0], tag1[1], tag1[0]))
          else:
            if "&" in tag1[1]:
              teams.append("{} ({}, {}, {})".format(faction1, team1[0], tag1[0], tag1[1]))
            else:
              teams.append("{} ({}, {} & {})".format(faction1, team1[0], tag1[0], tag1[1]))
        else:
          if "&" in tag1[0]:
            if "&" in tag1[1]: 
              teams.append("{}, {}, {} ({})".format(team1[0], tag1[0], tag1[1], fed1.upper()))
            else:
              teams.append("{}, {}, {} ({})".format(team1[0], tag1[1], tag1[0], fed2.upper()))
          else:
            if "&" in tag1[1]:
              teams.append("{}, {}, {} ({})".format(team1[0], tag1[0], tag1[1], fed1.upper()))
            else:
              teams.append("{}, {} & {} ({})".format(team1[0], tag1[0], tag1[1], fed1.upper()))
          
      if not tag2:
        if fed2 == "":
          teams.append("{} ({}, {}, {}, {} & {})".format(faction2,team2[0],team2[1],team2[2],team2[3], team2[4]))
        else:
          teams.append("{}, {}, {}, {} & {} ({})".format(team2[0],team2[1],team2[2],team2[3], team2[4], fed2.upper()))
      elif len(tag2) == 1:
        if fed2 == "":
          if "&" in tag2[0]:
            teams.append("{} ({}, {}, {}, {})".format(faction2,team2[0],team2[1], team2[2], tag2[0]))
          else:
            teams.append("{} ({}, {}, {} & {})".format(faction2,team2[0],team2[1], team2[2],tag2[0]))
        else:
          if "&" in tag2[0]:
            teams.append("{}, {}, {}, {} ({})".format(team2[0],team2[1], team2[2], tag2[0], fed2.upper()))
          else:
            teams.append("{}, {}, {} & {} ({})".format(team2[0],team2[1], team2[2], tag2[0], fed2.upper()))
      elif len(tag2) == 2:
        if fed2 == "":
          if "&" in tag2[0]:
            if "&" in tag2[1]:
              teams.append("{} ({}, {}, {})".format(faction2, team2[0], tag2[0], tag2[1]))
            else:
              teams.append("{} ({}, {}, {})".format(faction2, team2[0], tag2[1], tag2[0]))
          else:
            if "&" in tag2[1]:
              teams.append("{} ({}, {}, {})".format(faction2, team2[0], tag2[0], tag2[1]))
            else:
              teams.append("{} ({}, {} & {})".format(faction2, team2[0], tag2[0], tag2[1]))
        else:
          if "&" in tag2[0]:
            if "&" in tag2[1]: 
              teams.append("{}, {}, {} ({})".format(team2[0], tag2[0], tag2[1], fed2.upper()))
            else:
              teams.append("{}, {}, {} ({})".format(team2[0], tag2[1], tag2[0], fed2.upper()))
          else:
            if "&" in tag2[1]:
              teams.append("{}, {}, {} ({})".format(team2[0], tag2[0], tag2[1], fed2.upper()))
            else:
              teams.append("{}, {} & {} ({})".format(team2[0], tag2[0], tag2[1], fed2.upper()))
          
    firstmatch = "{} vs {}\n\n".format(teams[0], teams[1])
    usedwrestlers.extend(team1)
    usedwrestlers.extend(team2)
    
    if tag1:
      team1.extend(tag1)
    if tag2:
      team2.extend(tag2)
    matchresults["first"] = [team1, faction1, team2, faction2]
    
    team1 = []
    team2 = []
    tag1 = []
    tag2 = []
    teams = []
    fed1 = ""
    fed2 = ""
    faction1 = ""
    faction2 = ""
    
    prob = random.randint(0,100)
    dec = 0
    if prob < 70:
      faction1 = random.choice(list(stable_master.keys()))
      for w in usedwrestlers:
        if w in stable_master[faction1]:
          dec -= 1
      while (len(stable_master[faction1]) + dec) < 3:
        dec = 0
        faction1 = random.choice(list(stable_master.keys()))
        for w in usedwrestlers:
          if w in stable_master[faction1]:
            dec -= 1
    else:
      fed1 = random.choice(list(wrestlers.keys()))
      
    prob = random.randint(0,100)
    dec = 0
    if prob < 70:
      faction2 = random.choice(list(stable_master.keys()))
      while (faction1 == faction2 or (faction1 == "Lifeblood" and faction2 == "Taguchi Japan")
            or (faction2 == "Lifeblood" and faction1 == "Taguchi Japan")):
        faction2 = random.choice(list(stable_master.keys()))
      for w in usedwrestlers:
        if w in stable_master[faction2]:
          dec -= 1
      while (len(stable_master[faction2]) + dec) < 3:
        dec = 0
        faction2 = random.choice(list(stable_master.keys()))
        for w in usedwrestlers:
          if w in stable_master[faction2]:
            dec -= 1
    else:
      fed2 = random.choice(list(wrestlers.keys()))
      
    for i in range(3):
      if not team1:
        if fed1 == "":
          if len(stable_master[faction1]) == 3:
            team1.extend(stable_master[faction1])
          else:
            wrestler = random.choice(stable_master[faction1])
            while wrestler in usedwrestlers:
              wrestler = random.choice(stable_master[faction1])
            team1.append(wrestler)
        else:
          wrestler = random.choice(wrestlers[fed1])
          while wrestler in usedwrestlers or wrestler in factionbois:
            wrestler = random.choice(wrestlers[fed1])
          team1.append(wrestler)
      elif len(team1) == 3:
        pass
      else:
        if fed1 == "":
          wrestler = random.choice(stable_master[faction1])
          while wrestler in usedwrestlers or wrestler in team1 or wrestler in team2:
            wrestler = random.choice(stable_master[faction1])
        else:
          wrestler = random.choice(wrestlers[fed1])
          while wrestler in usedwrestlers or wrestler in team1 or wrestler in team2 or wrestler in factionbois:
            wrestler = random.choice(wrestlers[fed1])
        team1.append(wrestler)
        
      if not team2:
        if fed2 == "":
          if len(stable_master[faction2]) == 3:
            team2.extend(stable_master[faction2])
          else:
            wrestler = random.choice(stable_master[faction2])
            while wrestler in usedwrestlers:
              wrestler = random.choice(stable_master[faction2])
            team2.append(wrestler)
        else:
          wrestler = random.choice(wrestlers[fed2])
          while wrestler in usedwrestlers or wrestler in factionbois:
            wrestler = random.choice(wrestlers[fed2])
          team2.append(wrestler)
      elif len(team2) == 3:
        pass
      else:
        if fed2 == "":
          wrestler = random.choice(stable_master[faction2])
          while wrestler in usedwrestlers or wrestler in team1 or wrestler in team2:
            wrestler = random.choice(stable_master[faction2])
        else:
          wrestler = random.choice(wrestlers[fed2])
          while wrestler in usedwrestlers or wrestler in team1 or wrestler in team2 or wrestler in factionbois:
            wrestler = random.choice(wrestlers[fed2])
        team2.append(wrestler)
        
        
    
        
    checkteams(team1, faction1, tag1)
    checkteams(team2, faction2, tag2)
    
    if not tag1:
      if fed1 == "":
        teams.append("{} ({}, {} & {})".format(faction1,team1[0],team1[1],team1[2]))
      else:
        teams.append("{}, {} & {} ({})".format(team1[0],team1[1],team1[2], fed1.upper()))
    else:
      if fed1 == "":
        if "&" in tag1[0]:
          teams.append("{} ({}, {})".format(faction1,team1[0],tag1[0]))
        else:
          teams.append("{} ({} & {})".format(faction1,team1[0],tag1[0]))
      else:
        if "&" in tag1[0]:
          teams.append("{}, {} ({})".format(team1[0], tag1[0], fed1.upper()))
        else:
          teams.append("{} & {} ({})".format(team1[0], tag1[0], fed1.upper()))
    if not tag2:
      if fed2 == "":
        teams.append("{} ({}, {} & {})".format(faction2, team2[0], team2[1], team2[2]))
      else:
        teams.append("{}, {} & {} ({})".format(team2[0],team2[1], team2[2], fed2.upper()))
    else:
      if fed2 == "":
        if "&" in tag2[0]:
          teams.append("{} ({}, {})".format(faction2,team2[0],tag2[0]))
        else:
          teams.append("{} ({} & {})".format(faction2,team2[0],tag2[0]))
      else:
        if "&" in tag2[0]:
          teams.append("{}, {} ({})".format(team2[0], tag2[0], fed2.upper()))
        else:
          teams.append("{} & {} ({})".format(team2[0], tag2[0], fed2.upper()))
        
    secondmatch = "{} vs {}\n\n".format(teams[0], teams[1])
    usedwrestlers.extend(team1)
    usedwrestlers.extend(team2)
    
    if tag1:
      team1.extend(tag1)
    if tag2:
      team2.extend(tag2)
    matchresults["second"] = [team1, faction1, team2, faction2]
    
    msg = header + firstmatch + secondmatch + femmatch + tagmatch + midmatch2 + midmatch + mematch
    done = False
    
    await client.send_message(message.channel, "", embed = e)
    await client.send_message(message.channel, msg)
    
  if message.content.startswith("!results"):
    team1 = ""
    team2 = ""
    if matchresults["first"][1] == "":
      if len(matchresults["first"][0]) == 3: 
        team1 = "{}, {} & {}".format(matchresults["first"][0][0], matchresults["first"][0][1], matchresults["first"][0][2])
      elif len(matchresults["first"][0]) == 4:
        team1 = "{}, {}, {} & {}".format(matchresults["first"][0][0], matchresults["first"][0][1], matchresults["first"][0][2], matchresults["first"][0][3])
      elif len(matchresults["first"][0]) == 5:
        team1 = "{}, {}, {}, {} & {}".format(matchresults["first"][0][0], matchresults["first"][0][1], matchresults["first"][0][2], matchresults["first"][0][3], matchresults["first"][0][4])
    else:
      team1 = matchresults["first"][1]

    if matchresults["first"][3] == "":
      if len(matchresults["first"][2]) == 3: 
        team2 = "{}, {} & {}".format(matchresults["first"][2][0], matchresults["first"][2][1], matchresults["first"][2][2])
      elif len(matchresults["first"][2]) == 4:
        team2 = "{}, {}, {} & {}".format(matchresults["first"][2][0], matchresults["first"][2][1], matchresults["first"][2][2], matchresults["first"][2][3])
      elif len(matchresults["first"][2]) == 5:
        team2 = "{}, {}, {}, {} & {}".format(matchresults["first"][2][0], matchresults["first"][2][1], matchresults["first"][2][2], matchresults["first"][2][3], matchresults["first"][2][4])
    else:
      team2 = matchresults["first"][3]

    winningint = -1
    losingint = -1
    finisher = ""
    prob = random.randint(1,100)
    if prob <= 50:
      winningteam = team1
      losingteam = team2
      winner = random.choice(matchresults["first"][0])
      if winner in list(tag_master.keys()):
        winner = random.choice(tag_master[winner])
      loser = random.choice(matchresults["first"][2])
      if loser in list(tag_master.keys()):
        loser = random.choice(tag_master[loser])
      winningint = 0
      losingint = 2
    else:
      winningteam = team2
      losingteam = team1
      winner = random.choice(matchresults["first"][2])
      if winner in list(tag_master.keys()):
        winner = random.choice(tag_master[winner])
      loser = random.choice(matchresults["first"][0])
      if loser in list(tag_master.keys()):
        loser = random.choice(tag_master[loser])
      winningint = 2
      losingint = 0
        
    

    first = "- In the opening match, {} defeated {} when {} pinned {}.\n\n".format(winningteam, losingteam, winner, loser)
    
    usedtags = []
    for w in matchresults["first"][winningint]:
      if w in list(tag_master.keys()):
        if w not in usedtags:
          usedtags.append(w)
          for t in tag_master[w]:
            if t in winloss:
              [win, loss, streak] = winloss[t]
              winloss[t] = [win + 1, loss, streak + 1]
            else:
              winloss[t] = [1, 0, 1]
      else:
        if w in winloss:
          [win, loss, streak] = winloss[w]
          winloss[w] = [win+1, loss, streak+1]
        else:
          winloss[w] = [1, 0, 1]
    for l in matchresults["first"][losingint]:
      if l in list(tag_master.keys()):
        if l not in usedtags:
          usedtags.append(l)
          for t in tag_master[l]:
            if t in winloss:
              [win, loss, streak] = winloss[t]
              winloss[t] = [win, loss + 1, 0]
            else:
              winloss[t] = [0, 1, 0]
      else:
        if l in winloss:
          [win, loss, streak] = winloss[l]
          winloss[l] = [win, loss + 1, 0]
        else:
          winloss[l] = [0, 1, 0]
          
          

    if matchresults["second"][1] == "":
      if len(matchresults["second"][0]) == 3: 
        team1 = "{}, {} & {}".format(matchresults["second"][0][0], matchresults["second"][0][1], matchresults["second"][0][2])
      elif len(matchresults["second"][0]) == 2:
        team1 = "{} & {}".format(matchresults["second"][0][0], matchresults["second"][0][1])
    else:
      team1 = matchresults["second"][1]

    if matchresults["second"][3] == "":
      if len(matchresults["second"][2]) == 3: 
        team2 = "{}, {} & {}".format(matchresults["second"][2][0], matchresults["second"][2][1], matchresults["second"][2][2])
      elif len(matchresults["second"][2]) == 2:
        team2 = "{} & {}".format(matchresults["second"][2][0], matchresults["second"][2][1])
    else:
      team2 = matchresults["second"][3]

    winningint = -1
    losingint = -1
    prob = random.randint(1,100)
    if prob <= 50:
      winningteam = team1
      losingteam = team2
      winner = random.choice(matchresults["second"][0])
      if winner in list(tag_master.keys()):
        winner = random.choice(tag_master[winner])
      loser = random.choice(matchresults["second"][2])
      if loser in list(tag_master.keys()):
        loser = random.choice(tag_master[loser])
      winningint = 0
      losingint = 2
    else:
      winningteam = team2
      losingteam = team1
      winner = random.choice(matchresults["second"][2])
      if winner in list(tag_master.keys()):
        winner = random.choice(tag_master[winner])
      loser = random.choice(matchresults["second"][0])
      if loser in list(tag_master.keys()):
        loser = random.choice(tag_master[loser])
      winningint = 2
      losingint = 0

    second = "- In the 6-man match, {} defeated {} when {} pinned {}.\n\n".format(winningteam, losingteam, winner, loser)
    
    usedtags = []
    for w in matchresults["second"][winningint]:
      if w in list(tag_master.keys()):
        if w not in usedtags:
          usedtags.append(w)
          for t in tag_master[w]:
            if t in winloss:
              [win, loss, streak] = winloss[t]
              winloss[t] = [win + 1, loss, streak + 1]
            else:
              winloss[t] = [1, 0, 1]
      else:
        if w in winloss:
          [win, loss, streak] = winloss[w]
          winloss[w] = [win + 1, loss, streak + 1]
        else:
          winloss[w] = [1, 0, 1]
    for l in matchresults["second"][losingint]:
      if l in list(tag_master.keys()):
        if l not in usedtags:
          usedtags.append(l)
          for t in tag_master[l]:
            if t in winloss:
              [win, loss, streak] = winloss[t]
              winloss[t] = [win, loss + 1, 0]
            else:
              winloss[t] = [0, 1, 0]
      else:
        if l in winloss:
          [win, loss, streak] = winloss[l]
          winloss[l] = [win, loss + 1, 0]
        else:
          winloss[l] = [0, 1, 0]

    notinvolved = []
    finisher = ""
    prob = random.randint(1,100)
    change = False
    if prob <= 65:
      winner = matchresults["fem"][1]
      if len(matchresults["fem"]) == 5:
        loser = random.choice(matchresults["fem"][2:5])
      elif len(matchresults["fem"]) == 4:
        loser = random.choice(matchresults["fem"][2:4])
      elif len(matchresults["fem"]) == 3:
        loser = matchresults["fem"][2]
    else:
      change = True
      if len(matchresults["fem"]) == 5:
        winner = random.choice(matchresults["fem"][2:5])
        loser = random.choice(matchresults["fem"][1:5])
        while loser == winner:
          loser = random.choice(matchresults["fem"][1:5])
        for i in matchresults["fem"][1:]:
          if i != winner and i != loser:
            notinvolved.append(i)
      elif len(matchresults["fem"]) == 4:
        winner = random.choice(matchresults["fem"][2:4])
        loser = random.choice(matchresults["fem"][1:4])
        while loser == winner:
          loser = random.choice(matchresults["fem"][1:4])
        for i in matchresults["fem"][1:]:
          if i != winner and i != loser:
            notinvolved.append(i)
      elif len(matchresults["fem"]) == 3:
        winner = matchresults["fem"][2]
        loser = matchresults["fem"][1]
        
    finisher = finishers[winner]
    
    if finisher.startswith("The"):
      finish = " with {}".format(finisher)
    elif finisher.startswith("A") or finisher.startswith("E") or finisher.startswith("I") or finisher.startswith("O") or finisher.startswith("U"):
      finish = " with an {}".format(finisher)
    elif finisher == "":
      finish = ""
    else:
      finish = " with a {}".format(finisher)
          

    if change:
      if len(matchresults["fem"]) == 5:
        fem = "- In the {} match, {} defeated {}, {} & {} when {} pinned {}. **{} is the new {}**.\n\n".format(matchresults["fem"][0], winner, loser, notinvolved[0], notinvolved[1], winner, loser, winner, matchresults["fem"][0][0:-4])
      elif len(matchresults["fem"]) == 4:
        fem = "- In the {} match, {} defeated {} & {} when {} pinned {}. **{} is the new {}**.\n\n".format(matchresults["fem"][0], winner, loser, notinvolved[0], winner, loser, winner, matchresults["fem"][0][0:-4])
      elif len(matchresults["fem"]) == 3:
        fem = "- In the {} match, {} defeated {}{}. **{} is the new {}**.\n\n".format(matchresults["fem"][0], winner, loser, finish, winner, matchresults["fem"][0][0:-4])
      title_master[matchresults["fem"][0]][0] = winner 
    else:
      if len(matchresults["fem"]) == 5:
        fem = "- In the {} match, {} defeated {}, {} & {} when {} pinned {}. {} is still the {}.\n\n".format(matchresults["fem"][0], matchresults["fem"][1], 
                                                                                                        matchresults["fem"][2], matchresults["fem"][3], 
                                                                                                        matchresults["fem"][4], winner, loser, winner, matchresults["fem"][0][0:-4])
      elif len(matchresults["fem"]) == 4:
        fem = "- In the {} match, {} defeated {} & {} when {} pinned {}. {} is still the {}.\n\n".format(matchresults["fem"][0], matchresults["fem"][1], matchresults["fem"][2], 
                                                                                                    matchresults["fem"][3], winner, loser, winner, matchresults["fem"][0][0:-4])
      elif len(matchresults["fem"]) == 3:
        fem = "- In the {} match, {} defeated {}{}. {} is still the {}.\n\n".format(matchresults["fem"][0], winner, loser, finish, winner, matchresults["fem"][0][0:-4])
        
    if winner in winloss:
      [win, loss, streak] = winloss[winner]
      winloss[winner] = [win + 1, loss, streak + 1]
    else:
      winloss[winner] = [1, 0, 1]
    if loser in winloss:
      [win, loss, streak] = winloss[loser]
      winloss[loser] = [win, loss + 1, 0]
    else:
      winloss[loser] = [0, 1, 0]
    if notinvolved:
      for i in notinvolved:
        if i in winloss:
          [win, loss, streak] = winloss[i]
          winloss[i] = [win, loss + 1, 0]
        else:
          winloss[i] = [0, 1, 0]

    if change:
      if loser in past_titles:
        past_titles[loser].append(matchresults["fem"][0])
      else:
        past_titles[loser] = [matchresults["fem"][0]]
          
        
    finisher = ""
    participants = []
    prob = random.randint(1,100)
    bracket1 = False
    bracket2 = False
    if "(" in matchresults["tag"][1]:
      bracket1 = True
      index = matchresults["tag"][1].index('(')
      team1 = matchresults["tag"][1]
      matchresults["tag"][1] = matchresults["tag"][1][0:index-1]
      participants.extend(team1[index+1:-1].split(" & "))
    if "(" in matchresults["tag"][2]:
      bracket2 = True
      index = matchresults["tag"][2].index('(')
      team2 = matchresults["tag"][2]
      matchresults["tag"][2] = matchresults["tag"][2][0:index-1]
      participants.extend(team1[index+1:-1].split(" & "))

    change = False
    if prob <= 65:
      winningteam = matchresults["tag"][1]
      finisher = finishers[winningteam]
      losingteam = matchresults["tag"][2]
      winner = random.choice(tag_master[winningteam])
      if bracket1:
        while winner not in team1:
          winner = random.choice(tag_master[winningteam])
      if finisher == "":
        finisher = finishers[winner]
      loser = random.choice(tag_master[losingteam])
      if bracket2:
        while loser not in team2:
          loser = random.choice(tag_master[losingteam])
    else:
      change = True
      winningteam = matchresults["tag"][2]
      finisher = finishers[winningteam]
      losingteam = matchresults["tag"][1]
      winner = random.choice(tag_master[winningteam])
      if bracket2:
        while winner not in team2:
          winner = random.choice(tag_master[winningteam])
      if finisher == "":
        finisher = finishers[winner]
      loser = random.choice(tag_master[losingteam])
      if bracket1:
        while loser not in team1:
          loser = random.choice(tag_master[losingteam])
          
    if finisher.startswith("The"):
      finish = " with {}".format(finisher)
    elif finisher.startswith("A") or finisher.startswith("E") or finisher.startswith("I") or finisher.startswith("O") or finisher.startswith("U"):
      finish = " with an {}".format(finisher)
    elif finisher == "":
      finish = ""
    else:
      finish = " with a {}".format(finisher)
    

    if change:
      tag = "- In the {} match, {} defeated {} when {} beat {}{}. **{} are the new {}**.\n\n".format(matchresults["tag"][0], winningteam, losingteam, winner, loser, finish, winningteam, matchresults["tag"][0][0:-3])
      title_master[matchresults["tag"][0]][0] = winningteam
    else:
      tag = "- In the {} match, {} defeated {} when {} beat {}{}. {} are still the {}.\n\n".format(matchresults["tag"][0], winningteam, losingteam, winner, loser, finish, winningteam, matchresults["tag"][0][0:-3])
      
    if change:
      if bracket2 and not bracket1:
        for w in participants[0:2]:
          if w in winloss:
            [win, loss, streak] = winloss[w]
            winloss[w] = [win + 1, loss, streak + 1]
          else:
            winloss[w] = [1, 0, 1]
        for t in tag_master[losingteam]:
          if t in winloss:
            [win,loss,streak] = winloss[t]
            winloss[t] = [win, loss + 1, 0]
          else:
            winloss[t] = [0, 1, 0]
      elif bracket2 and bracket1:
        for w in participants[2:4]:
          if w in winloss:
            [win, loss, streak] = winloss[w]
            winloss[w] = [win + 1, loss, streak + 1]
          else:
            winloss[w] = [1, 0, 1]
        for w in participants[0:2]:
          if w in winloss:
            [win,loss,streak] = winloss[w]
            winloss[w] = [win, loss + 1, 0]
          else:
            winloss[w] = [0, 1, 0]
      else:
        for t in tag_master[winningteam]:
          if t in winloss:
            [win,loss,streak] = winloss[t]
            winloss[t] = [win + 1, loss, streak + 1]
          else:
            winloss[t] = [1, 0, 1]
        if bracket1:
          for w in participants[0:2]:
            if w in winloss:
              [win, loss, streak] = winloss[w]
              winloss[w] = [win, loss + 1, 0]
            else:
              winloss[w] = [0, 1, 0]
        else:
          for t in tag_master[losingteam]:
            if t in winloss:
              [win, loss, streak] = winloss[t]
              winloss[t] = [win, loss + 1, 0]
            else:
              winloss[t] = [0, 1, 0]
    else:
      if bracket1:
        for w in participants[0:2]:
          if w in winloss:
            [win, loss, streak] = winloss[w]
            winloss[w] = [win + 1, loss, streak + 1]
          else:
            winloss[w] = [1, 0, 1]
        if bracket2:
          for w in participants[2:4]:
            if w in winloss:
              [win,loss,streak] = winloss[w]
              winloss[w] = [win, loss + 1, 0]
            else:
              winloss[w] = [0, 1, 0]
        else:
          for t in tag_master[losingteam]:
            if t in winloss:
              [win, loss, streak] = winloss[t]
              winloss[t] = [win, loss + 1, 0]
            else:
              winloss[t] = [0, 1, 0]
      else:
        for t in tag_master[winningteam]:
          if t in winloss:
            [win,loss,streak] = winloss[t]
            winloss[t] = [win + 1, loss, streak + 1]
          else:
            winloss[t] = [1, 0, 1]
        if bracket2:
          for w in participants[2:4]:
            if w in winloss:
              [win,loss,streak] = winloss[w]
              winloss[w] = [win, loss + 1, 0]
            else:
              winloss[w] = [0, 1, 0]
        else:
          for t in tag_master[losingteam]:
            if t in winloss:
              [win, loss, streak] = winloss[t]
              winloss[t] = [win, loss + 1, 0]
            else:
              winloss[t] = [0, 1, 0]

    if change:
      for loser in tag_master[losingteam]:
        if loser in past_titles:
          past_titles[loser].append(matchresults["tag"][0])
        else:
          past_titles[loser] = [matchresults["tag"][0]]
      
    finisher = ""
    prob = random.randint(1,100)
    change = False
    if matchresults["mg"][0][-1] == "p":
      gimmick = False
    else:
      gimmick = True
    if gimmick:
      if prob <= 50:
        winner = matchresults["mg"][1]
        loser = matchresults["mg"][2]
      else:
        winner = matchresults["mg"][2]
        loser = matchresults["mg"][1]
    else:
      if prob <= 65:
        winner = matchresults["mg"][1]
        loser = matchresults["mg"][2]
      else:
        change = True
        winner = matchresults["mg"][2]
        loser = matchresults["mg"][1]
      
    finisher = finishers[winner]
    
    if finisher.startswith("The"):
      finish = " with {}".format(finisher)
    elif finisher.startswith("A") or finisher.startswith("E") or finisher.startswith("I") or finisher.startswith("O") or finisher.startswith("U"):
      finish = " with an {}".format(finisher)
    elif finisher == "":
      finish = ""
    else:
      finish = " with a {}".format(finisher)

    if change:
      if gimmick:
        mg = "- In their {}, {} defeated {}\n\n".format(matchresults["mg"][0], winner, loser)
      else:
        mg = "- In the {} match, {} defeated {}{}. **{} is the new {}**.\n\n".format(matchresults["mg"][0], winner, loser, finish, winner, matchresults["mg"][0][0:-4])
        title_master[matchresults["mg"][0]][0] = winner 
    else:
      if gimmick:
        mg = "- In their {}, {} defeated {}\n\n".format(matchresults["mg"][0], winner, loser)
      else:
        mg = "- In the {} match, {} defeated {}{}. {} is still the {}.\n\n".format(matchresults["mg"][0], winner, loser, finish, winner, matchresults["mg"][0][0:-4])
        
    if winner in winloss:
      [win, loss, streak] = winloss[winner]
      winloss[winner] = [win + 1, loss, streak + 1]
    else:
      winloss[winner] = [1, 0, 1]
    if loser in winloss:
      [win, loss, streak] = winloss[loser]
      winloss[loser] = [win, loss + 1, 0]
    else:
      winloss[loser] = [0, 1, 0]

    if change:
      if loser in past_titles:
        past_titles[loser].append(matchresults["mg"][0])
      else:
        past_titles[loser] = [matchresults["mg"][0]]
        
      

    finisher = ""
    prob = random.randint(1,100)
    change = False
    if prob <= 65:
      winner = matchresults["MID"][1]
      loser = matchresults["MID"][2]
    else:
      change = True
      winner = matchresults["MID"][2]
      loser = matchresults["MID"][1]
           
    finisher = finishers[winner]
    
    if finisher.startswith("The"):
      finish = " with {}".format(finisher)
    elif finisher.startswith("A") or finisher.startswith("E") or finisher.startswith("I") or finisher.startswith("O") or finisher.startswith("U"):
      finish = " with an {}".format(finisher)
    elif finisher == "":
      finish = ""
    else:
      finish = " with a {}".format(finisher)

    if change:
      mid = "- In the {} match, {} defeated {}{}. **{} is the new {}**.\n\n".format(matchresults["MID"][0], winner, loser, finish, winner, matchresults["MID"][0][0:-4])
      title_master[matchresults["MID"][0]][0] = winner 
    else:
      mid = "- In the {} match, {} defeated {}{}. {} is still the {}.\n\n".format(matchresults["MID"][0], winner, loser, finish, winner, matchresults["MID"][0][0:-4])
      
    if winner in winloss:
      [win, loss, streak] = winloss[winner]
      winloss[winner] = [win + 1, loss, streak + 1]
    else:
      winloss[winner] = [1, 0, 1]
    if loser in winloss:
      [win, loss, streak] = winloss[loser]
      winloss[loser] = [win, loss + 1, 0]
    else:
      winloss[loser] = [0, 1, 0]

    if change:
      if loser in past_titles:
        past_titles[loser].append(matchresults["MID"][0])
      else:
        past_titles[loser] = [matchresults["MID"][0]]


    finisher = ""
    prob = random.randint(1,100)
    change = False
    if prob <= 65:
      winner = matchresults["ME"][1]
      loser = matchresults["ME"][2]
    else:
      change = True
      winner = matchresults["ME"][2]
      loser = matchresults["ME"][1]
      
    finisher = finishers[winner]
    
    if finisher.startswith("The"):
      finish = " with {}".format(finisher)
    elif finisher.startswith("A") or finisher.startswith("E") or finisher.startswith("I") or finisher.startswith("O") or finisher.startswith("U"):
      finish = " with an {}".format(finisher)
    elif finisher == "":
      finish = ""
    else:
      finish = " with a {}".format(finisher)

    if change:
      me = "- In the main event for the {}, {} defeated {}{}. **{} is the new {}**.".format(matchresults["ME"][0], winner, loser, finish, winner, matchresults["ME"][0][0:-4])
      title_master[matchresults["ME"][0]][0] = winner 
    else:
       me = "- In the main event for the {}, {} defeated {}{}. {} is still the {}.".format(matchresults["ME"][0], winner, loser, finish, winner, matchresults["ME"][0][0:-4]) 
        
    if winner in winloss:
      [win, loss, streak] = winloss[winner]
      winloss[winner] = [win + 1, loss, streak + 1]
    else:
      winloss[winner] = [1, 0, 1]
    if loser in winloss:
      [win, loss, streak] = winloss[loser]
      winloss[loser] = [win, loss + 1, 0]
    else:
      winloss[loser] = [0, 1, 0]

    if change:
      if loser in past_titles:
        past_titles[loser].append(matchresults["ME"][0])
      else:
        past_titles[loser] = [matchresults["ME"][0]]

    msg = matchresults["header"] + first + second + fem + tag + mg + mid + me

    await client.send_message(message.channel, msg)
    
  if message.content.startswith("!titles"):
    sort = False
    fed = ""
    wrestler = ""
    team = ""
    fem = ""
    msg = ""
    param = message.content[8:]
    for k, v in titles.items():
      if k.lower() == param.lower():
        fed = param.lower()
    if fed != "":
      for title, data in titles[fed].items():
        if data[1] == "TRIO":
          champions = data[0][0] + ", " + data[0][1] + " & " + data[0][2]
          for k, v in stable_master.items():
            if data[0][0] in v:
              if data[0][1] in v:
                if data[0][2] in v:
                  champions = k + " (" + champions + ")"
          msg += "{}: {}\n".format(title, champions)
        else:
          msg += "{}: {}\n".format(title, data[0])
    else:
      for w in wrestlers_master:
        if w.lower() == param.lower():
          wrestler = param
      if wrestler != "":
        champs = []
        wrestlerteam = []
        for t, data in tag_master.items():
          if wrestler in data:
            if t not in wrestlerteam:
              wrestlerteam.append(t)
        for title, data in title_master.items():
          if data[0] == wrestler:
            champs.append(title)
          if data[0] in wrestlerteam:
            champs.append(title)
        if not champs:
          msg = "{} holds no titles.".format(wrestler)
        else:
          msg = "{} holds these titles: {}".format(wrestler, ", ".join(champs))
      else:
        for t, data in tag_master.items():
          if t.lower() == param.lower():
            team = param
        if team != "":
          champs = []
          for title, data in title_master.items():
            if data[0] == team:
              champs.append(title)
          if not champs:
            msg = "{} hold no titles.".format(team)
          else:
            msg = "{} hold these titles: {}".format(team, ", ".join(champs))
        else:
          for f in fem_master:
            if f.lower() == param.lower():
              fem = param
          if fem != "":
            champs = []
            for title, data in title_master.items():
              if data[0] == fem:
                champs.append(title)
            if not champs:
              msg = "{} hold no titles.".format(fem)
            else:
              msg = "{} hold these titles: {}".format(fem, ", ".join(champs))
          else:
            msg = "What the fuck is that parameter you nerd"
    await client.send_message(message.channel, msg)

  ### ROSTER COMMAND
  if message.content.startswith("!roster"):
    if len(message.content) == 7:
      await client.send_message(message.channel, "Please add a promotion parameter")
    else:
      company = message.content[8:].lower()
      if company in list(wrestlers.keys()):
        maineventerslist = maineventers[company]
        maineventerslist.sort()
        msg = "__**{} Roster**__\n".format(company.upper())
        msg += "**Main Eventers:** " + ", ".join(maineventerslist)
        wrestlers1 = wrestlers[company]
        wrestlers2 = []
        for wrestler in wrestlers1:
          if wrestler not in maineventerslist:
            wrestlers2.append(wrestler)
        wrestlers2.sort()
        msg += "\n**Midcard and Lowercard:** " + ", ".join(wrestlers2)
        womenlist = women.get(company)
        if womenlist == None:
          print("No women in promotion")
        else:
          womenlist.sort()
          msg += "\n**Women's Division:** " + ", ".join(womenlist) 
        await client.send_message(message.channel, msg)
      elif company in list(women.keys()):
        listofworkers = women[company]
        msg = "__**{} Roster**__\n".format(company.upper())
        msg += "**Wrestlers:** " + ", ".join(listofworkers)
        await client.send_message(message.channel, msg)
      else:
        msg = "Promotion not recognized"
        await client.send_message(message.channel, msg)

  ## FACTION COMMAND
  if message.content.startswith("!faction"):
    if len(message.content) == 8:
      msg = "Please send with a faction name"
      await client.send_message(message.channel, msg)
    else:
      faction = message.content[9:]
      faction_display = ""
      faction_members = []
      faction_fed = ""
      for stable, members in stable_master.items():
        if stable.lower() == faction.lower():
          faction_display = stable
          faction_members = members
          break
      faction_members.sort()
      for fed, data in stables.items():
        for stable in list(data.keys()):
          if stable == faction_display:
            faction_fed = fed.upper()
            break
      msg = "__**{}**__\n".format(faction_display)
      msg += "**Promotion:** {}\n".format(faction_fed)
      msg += "**Members:** {}".format(", ".join(faction_members))
      await client.send_message(message.channel, msg)
    
  ### ADD WIN/LOSS RECORDS
  if message.content.startswith("!winloss"):
    if len(message.content) == 8:
      if winloss:
        top = []
        tie = ""
        highest = 0
        inc = False
        for i in range(10):
          for k, d in winloss.items():
            inc = False
            for s in top:
              if k in s:
                inc = True
            if inc:
              continue
            if d[0] == 0:
              continue
            if (d[0] / (d[0] + d[1])) / (1/(d[0])) > highest:
              highest = (d[0] / (d[0] + d[1])) / (1/(d[0]))
              tie = k
            elif (d[0] / (d[0] + d[1])) / (1/(d[0])) == highest:
              if tie == "":
                tie = k
              else:
                if d[0] > winloss[tie][0]:
                  tie = k
                elif d[0] == highest:
                  if d[1] < winloss[tie][1]:
                    tie = k
                  elif d[1] == winloss[tie][1]:
                    if d[2] > winloss[tie][2]:
                      tie = k
                    elif d[2] == winloss[tie][2]:
                      if k < tie:
                        tie = k
          if winloss[tie][2] == 0:
            top.append("{} - {} wins, {} losses\n".format(tie, winloss[tie][0], winloss[tie][1]))
          else:
            top.append("{} - {} wins, {} losses - **{} MATCH STREAK**\n".format(tie, winloss[tie][0], winloss[tie][1], winloss[tie][2]))
          tie = ""
          highest = 0
        msg = "__Top 10 Wrestlers Win/Loss Ratio__\n" + "".join(top)
                  
      else:
        msg = "No Win/Loss Data Found"
    else:
      param = message.content[9:]
      if param in winloss:
        [win, loss, streak] = winloss[param]
        if streak == 0:
          msg = "{} - {} wins, {} losses".format(param, win, loss)
        else:
          msg = "{} - {} wins, {} losses - **{} MATCH STREAK**".format(param, win, loss, streak)
      elif param == "streak":
        streaks = []
        hstreak = -1
        for k, d in winloss.items():
          [win, loss, streak] = winloss[k]
          if streak > hstreak:
            hstreak = streak
            streaks = []
            streaks.append([k, streak])
          elif streak == hstreak:
            streaks.append([k, streak])
        msg = "__Longest Current Streaks__\n"
        for s in streaks:
          msg += "{}: **{}**\n".format(s[0], s[1])
      else:
        msg = "That's Not Even A Real Parameter"
      
    await client.send_message(message.channel, msg)

  if message.content.startswith("!info"):
    if len(message.content) == 5:
      msg = "Usage: '!info [wrestler]'"
    else:
      param = message.content[6:]
      if param in wrestlers_master:
        feds = []
        for k, v in wrestlers.items():
          if param in v:
            feds.append(k.upper())
        if len(feds) > 1:
          msg = "**" + param + "** (" + feds[0] + "/" + feds[1] + ")"
        else:
          msg = "**" + param + "** (" + feds[0] + ")"
        msg += "\nTag Teams: "
        teams = []
        for k, v in tag_master.items():
          if param in v:
            teams.append(k)
        for team in teams:
          teammates = []
          for k,v in tag_master.items():
            if team == k:
              teammates = v[:]
          teammates.remove(param)
          msg += team + " (w/ " + " & ".join(teammates) + ")" + ", "
        if len(teams) != 0:
          msg = msg[:len(msg)-2]
        msg += "\nStables: "
        s = []
        for k, v in stable_master.items():
          if param in v:
            s.append(k)
        for stable in s:
          stablemates = []
          for k, v in stable_master.items():
            if k == stable:
              stablemates = v[:]
          stablemates.remove(param)
          stablemates.sort()
          msg += stable + " (w/ " + ", ".join(stablemates) + "), "
        if len(s) != 0:
          msg = msg[:len(msg)-2]
        msg += "\nTitles: "
        champs = []
        for k, v in title_master.items():
          if param == v[0]:
            champs.append(k)
          if v[0] in teams:
            champs.append(k)
          if v[1] == "TRIO":
            if param in v[0]:
              champs.append(k)
        for champ in champs:
          msg += champ + ", "
        if len(champs) != 0:
          msg = msg[:len(msg)-2]
        msg += "\nPast Titles: "
        pastchamps = []
        if param in past_titles:
          for k, v in past_titles.items():
            if param == k:
              pastchamps.extend(v)
        if pastchamps:
          msg += ", ".join(pastchamps)
      else:
        msg = "Parameter Not Recognised. Please Try Again."

    await client.send_message(message.channel, msg)

  if message.content.startswith("!rumble"):
    rumble_size = 30
    rumble_participants = []
    rumble_chance = {}
    rumble_eliminations = {}
    rumble_time = {}
    rumble_lines = [" was nearly eliminated.", " is holding on to the ropes.", " hit their finisher.", 
                    " got low-blowed.", " is dangling above the floor.", " narrowly escaped elimination.",
                    " taunts in the middle of the ring."
                    ]
    chosen_DB = []
    if len(message.content) != 7:
      command_sections = message.content.split()
      rumble_size = int(command_sections[1])
      if rumble_size > 100:
        msg = "Support for 100+ rumble participants has not been implemented yet."
        await client.send_message(message.channel, msg)
        return
    print(str(rumble_size) + " Person Rumble")
    for i in range(rumble_size):
      probability = random.randint(1,100)
      if probability <= 5:
        chosen_DB = legends
      else:
        chosen_DB = all_wrestlers
      if len(command_sections) == 2:
        rumble_participant = random.choice(chosen_DB)
        while rumble_participant in rumble_participants:
          rumble_participant = random.choice(chosen_DB)
      elif command_sections[2] == "m":
        rumble_participant = random.choice(wrestlers_master)
        while rumble_participant in rumble_participants:
          rumble_participant = random.choice(wrestlers_master)
      elif command_sections[2] == "f":
        rumble_participant = random.choice(fem_master)
        while rumble_participant in rumble_participants:
          rumble_participant = random.choice(fem_master)
      else:
        rumble_participant = random.choice(chosen_DB)
        while rumble_participant in rumble_participants:
          rumble_participant = random.choice(chosen_DB)
      rumble_participants.append(rumble_participant)
    rumble_entrant = rumble_participants.pop(0)
    rumble_chance[rumble_entrant] = 10
    rumble_eliminations[rumble_entrant] = 0
    rumble_time[rumble_entrant] = 0
    msg = "The #1 entrant in the Rumble is **" + rumble_entrant + "**."
    await client.send_message(message.channel, msg)
    time.sleep(4)
    rumble_entrant = rumble_participants.pop(0)
    rumble_chance[rumble_entrant] = 10
    rumble_eliminations[rumble_entrant] = 0
    rumble_time[rumble_entrant] = 0
    msg = "The #2 entrant in the Rumble is **" + rumble_entrant + "**."
    await client.send_message(message.channel, msg)
    time.sleep(4)
    for i in range(rumble_size - 2):
      for j in range(3):
        danger = random.choice(list(rumble_chance.keys()))
        probability = random.randint(1,100)
        if probability <= rumble_chance[danger]:
          eliminator = random.choice(list(rumble_chance.keys()))
          while eliminator == danger:
            eliminator = random.choice(list(rumble_chance.keys()))
          if probability != 1:
            msg = "**" + danger + " has been eliminated by " + eliminator + "!**"
            await client.send_message(message.channel, msg)
            for entrant in list(rumble_chance.keys()):
              rumble_time[entrant] = rumble_time[entrant] + 0.5
            rumble_eliminations[eliminator] = rumble_eliminations[eliminator] + 1
            rumble_chance.pop(danger, None)
            print("Still in the ring: " + ", ".join(list(rumble_chance.keys())))
            time.sleep(4)
          else:
            msg = "**" + danger + " and " + eliminator + " have eliminated each other!**"
            await client.send_message(message.channel, msg)
            for entrant in list(rumble_chance.keys()):
              rumble_time[entrant] = rumble_time[entrant] + 0.5
            rumble_eliminations[danger] = rumble_eliminations[danger] + 1
            rumble_eliminations[eliminator] = rumble_eliminations[eliminator] + 1
            rumble_chance.pop(danger, None)
            rumble_chance.pop(eliminator, None)
            print("Still in the ring: " + ", ".join(list(rumble_chance.keys())))
            time.sleep(4)
        else:
          msg = danger + random.choice(rumble_lines)
          rumble_chance[danger] = rumble_chance[danger] + 10
          print(danger + " is now on a chance of " + str(rumble_chance[danger]))
          await client.send_message(message.channel, msg)
          for entrant in list(rumble_chance.keys()):
            rumble_time[entrant] = rumble_time[entrant] + 0.5
          time.sleep(4)
        if len(list(rumble_chance.keys())) <= 1:
          break
      for entrant in list(rumble_chance.keys()):
        rumble_time[entrant] = rumble_time[entrant] + 0.5
      rumble_entrant = rumble_participants.pop(0)
      rumble_chance[rumble_entrant] = 10
      rumble_eliminations[rumble_entrant] = 0
      rumble_time[rumble_entrant] = 0
      entry_number = 3 + i
      msg = "The #" + str(entry_number) + " entrant in the Rumble is **" + rumble_entrant + "**."
      await client.send_message(message.channel, msg)
      time.sleep(4)
    while len(list(rumble_chance.keys())) > 1:
      danger = random.choice(list(rumble_chance.keys()))
      probability = random.randint(1,100)
      if probability <= rumble_chance[danger]:
        eliminator = random.choice(list(rumble_chance.keys()))
        while eliminator == danger:
          eliminator = random.choice(list(rumble_chance.keys()))
        if probability != 1:
          msg = "**" + danger + " has been eliminated by " + eliminator + "!**"
          await client.send_message(message.channel, msg)
          for entrant in list(rumble_chance.keys()):
            rumble_time[entrant] = rumble_time[entrant] + 0.5
          rumble_eliminations[eliminator] = rumble_eliminations[eliminator] + 1
          rumble_chance.pop(danger, None)
          print(str(len(list(rumble_chance.keys()))) + " left in the Rumble: " + ", ".join(list(rumble_chance.keys())))
          time.sleep(4)
        else:
          msg = "**" + danger + " and " + eliminator + " have eliminated each other!**"
          await client.send_message(message.channel, msg)
          for entrant in list(rumble_chance.keys()):
            rumble_time[entrant] = rumble_time[entrant] + 0.5
          rumble_eliminations[danger] = rumble_eliminations[danger] + 1
          rumble_eliminations[eliminator] = rumble_eliminations[eliminator] + 1
          rumble_chance.pop(danger, None)
          rumble_chance.pop(eliminator, None)
          print(str(len(list(rumble_chance.keys()))) + " left in the Rumble: " + ", ".join(list(rumble_chance.keys())))
          time.sleep(4)
      else:
        msg = danger + random.choice(rumble_lines)
        rumble_chance[danger] = rumble_chance[danger] + 10
        print(danger + " is now on a chance of " + str(rumble_chance[danger]))
        await client.send_message(message.channel, msg)
        for entrant in list(rumble_chance.keys()):
          rumble_time[entrant] = rumble_time[entrant] + 0.5
        time.sleep(4)
    if len(list(rumble_chance.keys())) < 1:
      msg = "**Nobody has won the Rumble!**"
      await client.send_message(message.channel, msg)
    else:
      winner = list(rumble_chance.keys())[0]
      msg = "**" + winner + " has won the Rumble!**"
      await client.send_message(message.channel, msg)
      # MAIN EVENT PUSH CODE
      if rumble_size >= 15:
        if winner in wrestlers_master:
          if winner not in me_master:
            me_master.append(winner)
      # //
    # MOST ELIMINATIONS CODE
    elims = 0
    mostelims = []
    for k, v in rumble_eliminations.items():
      if v > elims:
        mostelims = [k]
        elims = v
      elif v == elims:
        mostelims.append(k)
    msg = " & ".join(mostelims) + " had the most eliminations with " + str(elims) + "."
    await client.send_message(message.channel, msg)
    # //
    # IRON MAN CODE
    best_time = 0
    iron_man = []
    for k, v in rumble_time.items():
      if v > best_time:
        iron_man = [k]
        best_time = v
      elif v == best_time:
        iron_man.append(k)
    msg = " & ".join(iron_man) + " spent the longest time in the ring, with " + str(best_time) + " minutes."
    await client.send_message(message.channel, msg)
      

    
@client.event
async def on_ready():
  print('Logged in as')
  print(client.user.name)
  print(client.user.id)
  servers = []
  for s in client.servers:
    servers.append(s.name)
  print(servers)
  print('-------')

# %%
client.run(TOKEN)
# Out:
# Logged in as
# The FantasyBooker
# 392666485690073088
# ['FantasyBookers', 'test']
# -------
# Champion = Kotaro Suzuki, Yoshinari Ogawa
# Title = GHC Junior Heavyweight Tag Team Championship
# Challenger = Jado & Gedo
# ['Ryusuke Taguchi', 'Hiroshi Tanahashi', 'David Finlay', 'Juice Robinson'] ['David Finlay', 'Juice Robinson']
